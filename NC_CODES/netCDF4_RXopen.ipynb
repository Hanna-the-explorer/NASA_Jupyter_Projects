# %%
import xarray
import xarray as xr
import netCDF4
import numpy as np 
import matplotlib.pyplot as plt

# %%
path = '/mnt/beegfs/home/hbridgham2021/Desktop/NASA_DATA/Data_archive_did_not_open/Data_ex_1/A2021274.L3b_DAY_IOP.x.nc'
ds = xr.open_dataset(path)
nc = netCDF4.Dataset(path)

# %%
nc
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     product_name: A2021274.L3b_DAY_IOP.x.nc
#     title: MODIS Level-3 Binned Data
#     instrument: MODIS
#     platform: Aqua
#     temporal_range: day
#     start_orbit_number: 103245
#     end_orbit_number: 103261
#     date_created: 2022008214354000
#     processing_version: unspecified
#     history: /sdps/sdpsoper/Science/OCSSW/V2021.1/bin/l3bin ifile=A2021274.L3b_DAY_IOP.nc ofile=A2021274.L3b_DAY_IOP.x.nc latnorth=35.0600 latsouth=21.6000 lonwest=-98.8600 loneast=-78.9000
#     time_coverage_start: 2021-10-01T00:00:00.000Z
#     time_coverage_end: 2021-10-02T02:30:00.000Z
#     northernmost_latitude: 30.645834
#     southernmost_latitude: 21.604166
#     easternmost_longitude: -78.854195
#     westernmost_longitude: -94.414665
#     geospatial_lat_max: 30.64583396911621
#     geospatial_lat_min: 21.60416603088379
#     geospatial_lon_max: -78.85419464111328
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes: (12/48)
#     product_name:                      A2021274.L3b_DAY_IOP.x.nc
#     title:                             MODIS Level-3 Binned Data
#     instrument:                        MODIS
#     platform:                          Aqua
#     temporal_range:                    day
#     start_orbit_number:                103245
#     ...                                ...
#     processing_level:                  L3 Binned
#     cdm_data_type:                     point
#     identifier_product_doi_authority:  https://dx.doi.org
#     identifier_product_doi:            10.5067/AQUA/MODIS/L3B/IOP/2018
#     keywords_vocabulary:               NASA Global Change Master Directory (G...
#     keywords:                          Earth Science > Oceans > Ocean Optics ...

# %%
data = xr.open_dataset(path, group='geophysical_data')
navigation = xr.open_dataset(path, group='navigation_data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /mnt/beegfs/home/hbridgham2021/.conda/envs/bugs/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _nc4_require_group(ds, group, mode, create_group)
#     177             try:
# --> 178                 ds = ds.groups[key]
#     179             except KeyError as e:
#
# KeyError: 'geophysical_data'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-628b28cbbafe> in <module>()
# ----> 1 data = xr.open_dataset(path, group='geophysical_data')
#       2 navigation = xr.open_dataset(path, group='navigation_data')
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c5d84736ba45> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import numpy as np

# %%
plt.pcolormesh(data[sst])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-45eedaebfe18> in <module>()
# ----> 1 plt.pcolormesh(data[sst])
#
# NameError: name 'data' is not defined

# %%
x = np.arange(1,7)
y = np.array(1,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3eb42ab79406> in <module>()
# ----> 1 x = no.arange(1.7)
#
# NameError: name 'no' is not defined
