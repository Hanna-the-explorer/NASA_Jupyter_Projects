# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme(style="ticks")

# %matplotlib inline

# %%
ds = pd.read_csv('Hanna_files/PW_ABS_+_Fe.csv')
ds
# Out:
#          Section  Sample ID Treatment   Campaign Location  Depth (mm)  \
# 0       ST. 14 0     214900     PWP2F  GOM2021FA   Stn 14         0.0
# 1       ST. 14 1     214901     PWP2F  GOM2021FA   Stn 14         3.5
# 2      ST. 14 10     214910     PWP2F  GOM2021FA   Stn 14        77.0
# 3      ST. 14 11     214911     PWP2F  GOM2021FA   Stn 14        87.0
# 4      ST. 14 12     214912     PWP2F  GOM2021FA   Stn 14        99.5
# ..           ...        ...       ...        ...      ...         ...
# 267     St.MK 14     214614     PWP2F  GOM2021FA   Stn MK       137.0
# 268  St.MK 17+18     214617     PWP2F  GOM2021FA   Stn MK       212.0
# 269      St.MK 5     214605     PWP2F  GOM2021FA   Stn MK        35.0
# 270      St.MK 6     214606     PWP2F  GOM2021FA   Stn MK        42.0
# 271      St.Mk 8     214608     PWP2F  GOM2021FA   Stn MK        62.0
#
#      Fe2 Conc (uM)  FeT Conc (uM)  Fe3 Conc (uM) Station  ...    Sample  \
# 0              NaN            NaN            NaN   St.14  ...  214900.0
# 1              NaN            NaN            NaN   St.14  ...  214901.0
# 2            3.386         65.196         61.811   St.14  ...  214910.0
# 3            0.657         54.821         54.164   St.14  ...  214911.0
# 4              NaN            NaN            NaN   St.14  ...       NaN
# ..             ...            ...            ...     ...  ...       ...
# 267          0.238            NaN            NaN   St.MK  ...  214614.0
# 268          0.119            NaN            NaN   St.MK  ...       NaN
# 269         22.805        151.044        128.239   St.MK  ...  214605.0
# 270         13.367        114.787        101.420   St.MK  ...  214606.0
# 271          8.872         51.262         42.390   St.MK  ...  214608.0
#
#          a350      a412      a444    SS 275-295  275-295 offset  SS 350-400  \
# 0     4.16843   7.43869   7.30051 -2.442451e-02        1.813314   -0.014208
# 1     3.13208   4.76721   4.03025  6.122862e-02        3.480187   -0.027231
# 2    29.68567  13.56467   6.79385  9.225045e-03       25.190117    0.015236
# 3    -0.34545 -24.36574 -29.82385  8.970000e-08       -0.458366    0.003717
# 4         NaN       NaN       NaN           NaN             NaN         NaN
# ..        ...       ...       ...           ...             ...         ...
# 267   0.16121  -1.19756  -1.42786  1.182717e-02      -42.371640    0.035701
# 268       NaN       NaN       NaN           NaN             NaN         NaN
# 269  92.37333  61.58222  46.19818  3.530597e-03       63.353493    0.006536
# 270  69.43545  39.63463  26.48450  4.018912e-03       29.113273    0.006533
# 271  27.65903  12.34408   7.36960  5.871716e-03        4.510802    0.004178
#
#      350-400 offset  SS 275-700  275-700 offset
# 0          1.558084   -0.000199      -44.478791
# 1          2.584046    0.000045       -6.754887
# 2          1.825371    0.010642       -3.766672
# 3        -68.456538    0.007710      -33.188724
# 4               NaN         NaN             NaN
# ..              ...         ...             ...
# 267       -1.817071    0.057144        0.230672
# 268             NaN         NaN             NaN
# 269        4.856304    0.005814       -2.590926
# 270      -18.624746    0.005858      -12.322850
# 271      -44.957012    0.010375        0.897872
#
# [272 rows x 22 columns]

# %%
ds.Location.unique()
# Out:
# array(['Stn 14', 'Stn 15', 'Stn 4', 'Stn 5b', 'Stn 9', 'Stn MK', 'Stn 11',
#        'Stn 12', 'Stn 13', 'Stn 16', 'Stn 2', 'Stn 7'], dtype=object)

# %%
ds[ds['Location']=='Stn 14']
# Out:
#       Section  Sample ID Treatment   Campaign Location  Depth (mm)  \
# 0    ST. 14 0     214900     PWP2F  GOM2021FA   Stn 14         0.0
# 1    ST. 14 1     214901     PWP2F  GOM2021FA   Stn 14         3.5
# 2   ST. 14 10     214910     PWP2F  GOM2021FA   Stn 14        77.0
# 3   ST. 14 11     214911     PWP2F  GOM2021FA   Stn 14        87.0
# 4   ST. 14 12     214912     PWP2F  GOM2021FA   Stn 14        99.5
# 5   ST. 14 13     214913     PWP2F  GOM2021FA   Stn 14       114.5
# 6   ST. 14 14     214914     PWP2F  GOM2021FA   Stn 14       129.5
# 7   ST. 14 15     214915     PWP2F  GOM2021FA   Stn 14       144.5
# 8   ST. 14 16     214916     PWP2F  GOM2021FA   Stn 14       162.0
# 9   ST. 14 17     214917     PWP2F  GOM2021FA   Stn 14       182.0
# 10  ST. 14 18     214918     PWP2F  GOM2021FA   Stn 14       202.0
# 11  ST. 14 19     214919     PWP2F  GOM2021FA   Stn 14       222.0
# 12   ST. 14 2     214902     PWP2F  GOM2021FA   Stn 14        10.5
# 13  ST. 14 20     214920     PWP2F  GOM2021FA   Stn 14       247.0
# 14  ST. 14 21     214921     PWP2F  GOM2021FA   Stn 14       277.0
# 15  ST. 14 22     214922     PWP2F  GOM2021FA   Stn 14       307.0
# 16  ST. 14 23     214923     PWP2F  GOM2021FA   Stn 14       337.0
# 17   ST. 14 3     214903     PWP2F  GOM2021FA   Stn 14        17.5
# 18   ST. 14 4     214904     PWP2F  GOM2021FA   Stn 14        24.5
# 19   ST. 14 5     214905     PWP2F  GOM2021FA   Stn 14        31.5
# 20   ST. 14 6     214906     PWP2F  GOM2021FA   Stn 14        38.5
# 21   ST. 14 7     214907     PWP2F  GOM2021FA   Stn 14        47.0
# 22   ST. 14 8     214908     PWP2F  GOM2021FA   Stn 14        57.0
# 23   ST. 14 9     214909     PWP2F  GOM2021FA   Stn 14        67.0
#
#     Fe2 Conc (uM)  FeT Conc (uM)  Fe3 Conc (uM) Station  ...    Sample  \
# 0             NaN            NaN            NaN   St.14  ...  214900.0
# 1             NaN            NaN            NaN   St.14  ...  214901.0
# 2           3.386      65.196000         61.811   St.14  ...  214910.0
# 3           0.657      54.821000         54.164   St.14  ...  214911.0
# 4             NaN            NaN            NaN   St.14  ...       NaN
# 5           0.164      13.163000         12.999   St.14  ...  214913.0
# 6             NaN            NaN            NaN   St.14  ...       NaN
# 7           0.205      17.344000         17.139   St.14  ...  214915.0
# 8           0.328            NaN            NaN   St.14  ...       NaN
# 9           0.390      16.725000         16.335   St.14  ...  214917.0
# 10          0.369       6.349000          5.980   St.14  ...       NaN
# 11          0.226       6.349000          6.124   St.14  ...  214919.0
# 12          0.041            NaN            NaN   St.14  ...  214902.0
# 13          2.934      20.751000         17.817   St.14  ...       NaN
# 14          0.369      27.255000         26.886   St.14  ...  214921.0
# 15          0.226      33.914000         33.689   St.14  ...  214922.0
# 16            NaN      18.273558            NaN   St.14  ...  214923.0
# 17          1.559       2.013000          0.454   St.14  ...  214903.0
# 18          4.535      67.829000         63.294   St.14  ...  214904.0
# 19          6.792     103.757000         96.965   St.14  ...  214905.0
# 20          2.134      98.956000         96.822   St.14  ...  214906.0
# 21          6.033      93.691000         87.658   St.14  ...  214907.0
# 22          3.139      85.019000         81.879   St.14  ...  214908.0
# 23          2.319      72.785000         70.466   St.14  ...  214909.0
#
#         a350      a412      a444    SS 275-295  275-295 offset  SS 350-400  \
# 0    4.16843   7.43869   7.30051 -2.442451e-02        1.813314   -0.014208
# 1    3.13208   4.76721   4.03025  6.122862e-02        3.480187   -0.027231
# 2   29.68567  13.56467   6.79385  9.225045e-03       25.190117    0.015236
# 3   -0.34545 -24.36574 -29.82385  8.970000e-08       -0.458366    0.003717
# 4        NaN       NaN       NaN           NaN             NaN         NaN
# 5    3.08602  -1.68119  -4.00722  3.010653e-02        6.790465    0.005455
# 6        NaN       NaN       NaN           NaN             NaN         NaN
# 7   10.70895   8.24474   5.71144  2.643089e-02       15.252038    0.045623
# 8        NaN       NaN       NaN           NaN             NaN         NaN
# 9   10.84713   8.40595   5.84962  2.930730e-02       16.506100    0.043567
# 10       NaN       NaN       NaN           NaN             NaN         NaN
# 11   7.18536   5.78053   3.98419  3.159428e-02       10.137953    0.050493
# 12   3.47753   5.22781   4.12237  6.064868e-02        4.254717   -0.033456
# 13       NaN       NaN       NaN           NaN             NaN         NaN
# 14  14.64708   9.81078   7.00112  1.738066e-02       17.114326    0.033169
# 15  18.10158  11.49197   7.92232  1.996384e-02       24.782274    0.028237
# 16  11.26167   8.42898   5.96477  1.847193e-02       11.626083    0.039466
# 17  33.55471  20.03610  13.51861  1.147925e-02       28.988858    0.014370
# 18  52.11689  27.47479  17.94037  6.755811e-03       25.040243    0.012331
# 19  51.65629  24.75725  14.46284  6.053362e-03       19.976763    0.011229
# 20  51.01145  27.35964  18.00946  1.022141e-02       48.877758    0.011837
# 21  36.59467  16.32827   8.10656  1.023397e-02       33.115314    0.012408
# 22  43.41155  23.99726  15.95979  6.110851e-03       18.598213    0.013134
# 23  30.90626  13.01195   5.15872  7.698017e-03       17.508041    0.011604
#
#     350-400 offset  SS 275-700  275-700 offset
# 0         1.558084   -0.000199      -44.478791
# 1         2.584046    0.000045       -6.754887
# 2         1.825371    0.010642       -3.766672
# 3       -68.456538    0.007710      -33.188724
# 4              NaN         NaN             NaN
# 5       -13.240245    0.012947       -5.489739
# 6              NaN         NaN             NaN
# 7         7.658891    0.013330        2.833357
# 8              NaN         NaN             NaN
# 9         7.754662    0.013468        2.785625
# 10             NaN         NaN             NaN
# 11        5.372186    0.013551        1.939667
# 12        3.044214    0.000089      -27.896521
# 13             NaN         NaN             NaN
# 14        8.784349    0.013913        2.944222
# 15        9.487056    0.013287        2.992100
# 16        7.747613    0.014591        3.053023
# 17        8.972845    0.009746        1.702415
# 18        2.769659    0.009775        0.015334
# 19       -5.603183    0.009840       -3.580410
# 20        2.361958    0.009679        0.634142
# 21       -3.694698    0.010250       -5.151942
# 22        6.029779    0.009937        1.593552
# 23       -6.258492    0.010147       -6.489512
#
# [24 rows x 22 columns]

# %%
fig, ax = plt.subplots(figsize=(8,10))

station = 'Stn 14'

subset = ds[ds['Location']==station].sort_values('Depth (mm)')

ax.plot(subset['Fe2 Conc (uM)'], subset['Depth (mm)'], c='b')
ax.set_ylim(350, 0)
ax.set_xlim(0,7)
ax.set_ylabel('Depth [mm]', size=20)
ax.set_xlabel('Fe2 Conc (uM)', color='b', size=20)

newax = ax.twiny()

newax.plot(subset['a350'].values, subset['Depth (mm)'].values,
        'o', ls='-', c='r')

newax.set_frame_on(True)
newax.patch.set_visible(False)


ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top') 

newax.xaxis.set_ticks_position('top')
newax.xaxis.set_label_position('top')
newax.spines['top'].set_position(('outward', 50))
newax.set_xlabel('a350', color='r', size=20)
newax.set_xlim(0,500)

# # Make some room at the bottom
# fig.subplots_adjust(bottom=0.20)

# I'm guessing you want them both on the bottom...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(8,10))
#       3 station = 'Stn 14'
#       5 subset = ds[ds['Location']==station].sort_values('Depth (mm)')
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# %%
fig, axes = plt.subplots(3, 2, figsize=(8,8), sharey=True, sharex=True)
axes[1,1].plot(subset['Fe2 Conc (uM)'], subset['Depth (mm)'])
axes[0,0].set_label('Depth [mm]')
