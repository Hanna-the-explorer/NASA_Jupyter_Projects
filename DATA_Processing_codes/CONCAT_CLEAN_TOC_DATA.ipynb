# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns

# %%
#PULL UP ALL THE EXCELL FILES 
#files = glob.glob('../../../Data_Thesis/TOC/*/*.xlsx')
files = glob.glob('../../../OOC_Conferace_data/Fe/*FeT*.xlsx')
files

#make the path where you want to save eveything 
path_save = '../../../OOC_Conferace_data/Fe/FeT_BC_HALO.csv'
files
# Out:
# ['../../../OOC_Conferace_data/Fe\\BCFeT_HALO_ID2140.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2011.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2105.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2107.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2112.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2114.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2117.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2131.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2133_ID2138.xlsx',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2135.xlsx']

# %%
#make the last 
for f in files: 
    read_file = pd.read_excel (f, sheet_name='Final Results')
    name = f[:-5]
    read_file.to_csv (name + ".csv", index = None, header=True)
    
#make the new files list the csv files much safer
files = glob.glob('../../../OOC_Conferace_data/Fe/*FeT*.csv')
files
# Out:
# ['../../../OOC_Conferace_data/Fe\\BCFeT_HALO_ID2140.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2011.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2105.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2107.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2112.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2114.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2117.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2131.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2133_ID2138.csv',
#  '../../../OOC_Conferace_data/Fe\\BC_FeT_HALO_ID2135.csv']

# %%
#make function 
def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

# %%
#add it all up 
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)
df
# Out:
#           Treatment Campaign        Date Location Depth  Fe Conc (uM)  \
# Sample ID
# 214011        BCP2F     HALO  2021-10-12      NaN   NaN      1.666672
# 214012        BCP2F     HALO  2021-10-12      NaN   NaN      1.956488
# 214013        BCP2F     HALO  2021-10-12      NaN   NaN      1.729345
# 214014        BCP2F     HALO  2021-10-12      NaN   NaN      2.078302
# 214015        BCP2F     HALO  2021-10-12      NaN   NaN      1.829186
# ...             ...      ...         ...      ...   ...           ...
# 213516          P2F     HALO  2021-09-14     L001   NaN           NaN
# 213517          P2F     HALO  2021-09-14     L001   NaN           NaN
# 213518          P2F     HALO  2021-09-14     L001   NaN           NaN
# 213519          P2F     HALO  2021-09-14     L001   NaN           NaN
# 213520          P2F     HALO  2021-09-14     L001   NaN           NaN
#
#            Fe Conc (mg/L)  FeT (uM)  FeT (mg/L) Syringe  FeT Conc (uM)  \
# Sample ID
# 214011           0.093075       NaN         NaN     NaN            NaN
# 214012           0.109260       NaN         NaN     NaN            NaN
# 214013           0.096575       NaN         NaN     NaN            NaN
# 214014           0.116063       NaN         NaN     NaN            NaN
# 214015           0.102151       NaN         NaN     NaN            NaN
# ...                   ...       ...         ...     ...            ...
# 213516                NaN       NaN         NaN   BC2.1       0.895710
# 213517                NaN       NaN         NaN   BC2.2       0.995632
# 213518                NaN       NaN         NaN   BC2.3       0.988338
# 213519                NaN       NaN         NaN   BC2.4       0.777732
# 213520                NaN       NaN         NaN   BC2.5       0.750550
#
#            FeT Conc (mg/L) Notes
# Sample ID
# 214011                 NaN   NaN
# 214012                 NaN   NaN
# 214013                 NaN   NaN
# 214014                 NaN   NaN
# 214015                 NaN   NaN
# ...                    ...   ...
# 213516            0.050021   NaN
# 213517            0.055601   NaN
# 213518            0.055194   NaN
# 213519            0.043432   NaN
# 213520            0.041914   NaN
#
# [104 rows x 13 columns]

# %%
#clean up messy collumns drop the extra 
df["Notes"] = df["Notes"].fillna(df["Unnamed: 10"])
df = df.drop(['Unnamed: 10'], axis=1)

#add the 2 depth cols together drop the extra 
df["Depth"] = df["Depth"].fillna(df["Depth (m)"])
df = df.drop(["Depth (m)"], axis=1)

#put it in a nicer order 
df = df[['Treatment','Campaign','Date','Location','Depth','Time','NPOC Conc (mg/L)','TN Conc (mg/L)','NPOC Conc (uM)','TN Conc (uM)','Notes']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <module>
#       1 #clean up messy collumns drop the extra
# ----> 2 df["Notes"] = df["Notes"].fillna(df["Unnamed: 10"])
#       3 df = df.drop(['Unnamed: 10'], axis=1)
#       5 #add the 2 depth cols together drop the extra
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Unnamed: 10'

# %%
#save it for later 
df.to_csv(path_save)
