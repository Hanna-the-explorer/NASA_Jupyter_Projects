# %%
import numpy as np
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns
from sklearn.linear_model import LinearRegression
from math import sin, cos, sqrt, atan2, radians
import cmocean.cm as cmo

# %%
#PORE Water 
df = pd.read_csv('../../../Data_Thesis/Meta_data/PW_Salinity.csv', sep=',', index_col=0)
df['code'] = df['Site'].str.cat("_" + df['Project'])
df_pw = df[df['Sample_Type'] == 'PW']

# Step 1: Identify unique values in the "code" column of df_pw and convert them to a list
unique_codes = df_pw['code'].unique().tolist()

# Step 2: Filter rows in df based on whether their "code" is in the list of unique values
df = df[df['code'].isin(unique_codes)]

# %%
df_iron = pd.read_csv('../../../Data_Thesis/Iron/Iron.csv', sep=',', index_col=0)

#make all the spots labeled NA a nan value
df_iron = df_iron.replace('NA', np.nan)
df_iron = df_iron.replace('NA ', np.nan)

#make all BDL a 0 
df_iron.loc[df_iron['FeT_uM'] == 'BLD', 'FeT_uM'] = 0
df_iron.loc[df_iron['Fe2_uM'] == 'BLD', 'Fe2_uM'] = 0

# convert columns to numeric data type
df_iron['FeT_uM'] = pd.to_numeric(df_iron['FeT_uM'], errors='coerce')
df_iron['Fe2_uM'] = pd.to_numeric(df_iron['Fe2_uM'], errors='coerce')

df_iron['FeT_uM'] = df_iron['FeT_uM'].where(pd.notna(df_iron['FeT_uM']), other=np.nan)
df_iron['Fe2_uM'] = df_iron['Fe2_uM'].where(pd.notna(df_iron['Fe2_uM']), other=np.nan)

#make all negative a 0 
df_iron.loc[df_iron['FeT_uM'] < 0, 'FeT_uM'] = 0
df_iron.loc[df_iron['Fe2_uM'] < 0, 'Fe2_uM'] = 0

#calculate Fe +3 
df_iron['Fe3_uM'] = df_iron['FeT_uM'] - df_iron['Fe2_uM']
df_iron.loc[df_iron['Fe3_uM'] < 0, 'Fe3_uM'] = 0
df_iron.loc[df_iron['Fe2_uM'] > df_iron['FeT_uM'], 'Fe3_uM'] = 0
df_iron['Fe3_uM'] = pd.to_numeric(df_iron['Fe3_uM'], errors='coerce')
df_iron['Fe3_uM'] = df_iron['Fe3_uM'].where(pd.notna(df_iron['Fe3_uM']), other=np.nan)

#time feild 
df_iron['Fe2_Time'] = pd.to_numeric(df_iron['Fe2_Time'], errors='coerce')
df_iron['Fe2_Time'] = df_iron['Fe2_Time'].where(pd.notna(df_iron['Fe2_Time']), other=np.nan)

#time feild 
df_iron['FeT_Time'] = pd.to_numeric(df_iron['FeT_Time'], errors='coerce')
df_iron['FeT_Time'] = df_iron['FeT_Time'].where(pd.notna(df_iron['FeT_Time']), other=np.nan)

df_iron['code'] = df_iron['Location'] + '_' + df_iron['Campaign']

df_iron = df_iron.drop(['Treatment', 'FeT_Date', 'Campaign', 'Location', 'Type', 'code',
                       'FeT_mgL', 'FeT_Notes', 'FeT_Depth', 'FeT_Time', 'Fe2_Date', 'Fe2_mgL', 
                       'Fe2_Notes', 'Fe2_Time', 'Fe2_Depth', "FeT_uM"], axis=1)

df_iron = df_iron.rename_axis('Sample').reset_index()
df_iron.index = df_iron['Sample']
df_iron
# Out:
#                       Sample    Fe2_uM  Fe3_uM
# Sample
# 211911                211911  0.909000   2.146
# 211912                211912  0.638000   0.310
# 211913                211913  3.820000  22.356
# 211914                211914  2.641000  27.495
# 211915                211915  1.118000  14.217
# ...                      ...       ...     ...
# 225385                225385  3.130000   6.621
# 225386                225386       NaN     NaN
# 225388                225388  3.660000   6.138
# 221519+20          221519+20       NaN     NaN
# 221519+221520  221519+221520  2.286245     NaN
#
# [1916 rows x 3 columns]

# %%
df_doc = pd.read_csv('../../../Data_Thesis/TOC/TOC_GOM.csv', sep=',', index_col=0)

#make all BDL a 0 
df_doc.loc[df_doc['NPOC_uM'] == 'BLD', 'NPOC_uM'] = 0
df_doc.loc[df_doc['TN_uM'] == 'BLD', 'TN_uM'] = 0

df_doc.loc[df_doc['NPOC_uM'] < 0, 'NPOC_uM'] = 0
df_doc.loc[df_doc['TN_uM'] < 0, 'TN_uM'] = 0

#fix date time 
df_doc['date_time'] = pd.to_datetime(df_doc['Date'])
df_doc['Date'] = df_doc['date_time'].dt.date

df_doc['NPOC_uM'] = pd.to_numeric(df_doc['NPOC_uM'], errors='coerce')
df_doc['NPOC_uM'] = df_doc['NPOC_uM'].where(pd.notna(df_doc['NPOC_uM']), other=np.nan)

df_doc['TN_uM'] = pd.to_numeric(df_doc['TN_uM'], errors='coerce')
df_doc['TN_uM'] = df_doc['TN_uM'].where(pd.notna(df_doc['TN_uM']), other=np.nan)

df_doc['Time'] = pd.to_numeric(df_doc['Time'], errors='coerce')
df_doc['Time'] = df_doc['Time'].where(pd.notna(df_doc['Time']), other=np.nan)

df_doc['code'] = df_doc['Location'] + '_' + df_doc['Campaign']

df_doc = df_doc.rename_axis('Sample').reset_index()
df_doc.index = df_doc['Sample']

df_doc = df_doc.drop(['Depth', 'code', 'NPOC Conc (mg/L)', "TN Conc (mg/L)" , 'Treatment',
                     'Campaign', 'Location', "Type", "Time", "dil_fac", "date_time", "Notes", 'Sample'], axis=1)

# %%
df2 = df.join(df_doc)
df2 = df.join(df_iron)
df2
# Out:
#             Depth  Project Sample_Type   Salinity  Site       Lat        Lon  \
# Sample
# 214500  -0.200000  GOM21FA          PW  33.000000  St.4  28.79586 -90.702965
# 214501   0.350000  GOM21FA          PW  29.000000  St.4  28.79586 -90.702965
# 214502   1.050000  GOM21FA          PW  30.000000  St.4  28.79586 -90.702965
# 214503   1.750000  GOM21FA          PW  31.000000  St.4  28.79586 -90.702965
# 214504   2.450000  GOM21FA          PW  31.000000  St.4  28.79586 -90.702965
# ...           ...      ...         ...        ...   ...       ...        ...
# 221935  34.887980  GOM22SP          WC  35.896580  St.9  28.78732 -89.609723
# 221936  26.292327  GOM22SP          WC  35.832637  St.9  28.78732 -89.609723
# 221937  11.802347  GOM22SP          WC  35.090533  St.9  28.78732 -89.609723
# 221938   1.994000  GOM22SP          WC  24.039931  St.9  28.78732 -89.609723
# 221939   2.020327  GOM22SP          WC  23.180618  St.9  28.78732 -89.609723
#
#         Sed_density  Core_sal  water_density          code  Sample   Fe2_uM  \
# Sample
# 214500         2.65      31.0          1.031  St.4_GOM21FA  214500      NaN
# 214501         2.65      31.0          1.031  St.4_GOM21FA  214501    1.997
# 214502         2.65      31.0          1.031  St.4_GOM21FA  214502   85.061
# 214503         2.65      31.0          1.031  St.4_GOM21FA  214503  123.399
# 214504         2.65      31.0          1.031  St.4_GOM21FA  214504  105.162
# ...             ...       ...            ...           ...     ...      ...
# 221935         2.65      35.0          1.035  St.9_GOM22SP     NaN      NaN
# 221936         2.65      35.0          1.035  St.9_GOM22SP     NaN      NaN
# 221937         2.65      35.0          1.035  St.9_GOM22SP     NaN      NaN
# 221938         2.65      35.0          1.035  St.9_GOM22SP     NaN      NaN
# 221939         2.65      35.0          1.035  St.9_GOM22SP     NaN      NaN
#
#         Fe3_uM
# Sample
# 214500     NaN
# 214501   0.000
# 214502   1.042
# 214503  76.266
# 214504  82.713
# ...        ...
# 221935     NaN
# 221936     NaN
# 221937     NaN
# 221938     NaN
# 221939     NaN
#
# [444 rows x 14 columns]

# %%
from math import sin, cos, sqrt, atan2, radians

# Function to calculate Haversine distance
def haversine_distance(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1_rad = radians(lat1)
    lon1_rad = radians(lon1)
    lat2_rad = radians(lat2)
    lon2_rad = radians(lon2)

    # Radius of the Earth in kilometers
    earth_radius = 6371.0

    # Haversine formula
    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad
    a = sin(dlat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = earth_radius * c

    return distance

# Assuming you have a DataFrame called 'df' with columns "Lat" and "Lon"
# and you want to calculate distances from the point (29.154152, -89.239646)

# Latitude and Longitude of the reference point
ref_lat = 29.154152
ref_lon = -89.239646

# Calculate the distances using apply and lambda function
df['Distance_KM'] = df.apply(lambda row: haversine_distance(ref_lat, ref_lon, row['Lat'], row['Lon']), axis=1)

df
# Out:
#              Depth  Project Sample_Type   Salinity   Site       Lat  \
# Sample
# 214500   -0.200000  GOM21FA          PW  33.000000   St.4  28.79586
# 214501    0.350000  GOM21FA          PW  29.000000   St.4  28.79586
# 214502    1.050000  GOM21FA          PW  30.000000   St.4  28.79586
# 214503    1.750000  GOM21FA          PW  31.000000   St.4  28.79586
# 214504    2.450000  GOM21FA          PW  31.000000   St.4  28.79586
# ...            ...      ...         ...        ...    ...       ...
# 221937   11.802347  GOM22SP          WC  35.090533   St.9  28.78732
# 221938    1.994000  GOM22SP          WC  24.039931   St.9  28.78732
# 221939    2.020327  GOM22SP          WC  23.180618   St.9  28.78732
# 2218X1  263.450000  GOM22SP          WC  35.564000  St.15  28.94492
# 2218X2  263.450000  GOM22SP          WC  35.564000  St.15  28.94492
#
#               Lon  Sed_density  Core_sal  water_density           code  \
# Sample
# 214500 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214501 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214502 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214503 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214504 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# ...           ...          ...       ...            ...            ...
# 221937 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 221938 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 221939 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 2218X1 -88.858200          NaN       NaN            NaN  St.15_GOM22SP
# 2218X2 -88.858200          NaN       NaN            NaN  St.15_GOM22SP
#
#         Distance_KM
# Sample
# 214500   147.815867
# 214501   147.815867
# 214502   147.815867
# 214503   147.815867
# 214504   147.815867
# ...             ...
# 221937    54.404978
# 221938    54.404978
# 221939    54.404978
# 2218X1    43.773728
# 2218X2    43.773728
#
# [444 rows x 12 columns]

# %%
df_pw = df[df['Sample_Type'] == 'PW']
df_wc = df[df['Sample_Type'] == 'WC']

df
# Out:
#              Depth  Project Sample_Type   Salinity   Site       Lat  \
# Sample
# 214500   -0.200000  GOM21FA          PW  33.000000   St.4  28.79586
# 214501    0.350000  GOM21FA          PW  29.000000   St.4  28.79586
# 214502    1.050000  GOM21FA          PW  30.000000   St.4  28.79586
# 214503    1.750000  GOM21FA          PW  31.000000   St.4  28.79586
# 214504    2.450000  GOM21FA          PW  31.000000   St.4  28.79586
# ...            ...      ...         ...        ...    ...       ...
# 221937   11.802347  GOM22SP          WC  35.090533   St.9  28.78732
# 221938    1.994000  GOM22SP          WC  24.039931   St.9  28.78732
# 221939    2.020327  GOM22SP          WC  23.180618   St.9  28.78732
# 2218X1  263.450000  GOM22SP          WC  35.564000  St.15  28.94492
# 2218X2  263.450000  GOM22SP          WC  35.564000  St.15  28.94492
#
#               Lon  Sed_density  Core_sal  water_density           code  \
# Sample
# 214500 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214501 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214502 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214503 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# 214504 -90.702965         2.65      31.0          1.031   St.4_GOM21FA
# ...           ...          ...       ...            ...            ...
# 221937 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 221938 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 221939 -89.609723         2.65      35.0          1.035   St.9_GOM22SP
# 2218X1 -88.858200          NaN       NaN            NaN  St.15_GOM22SP
# 2218X2 -88.858200          NaN       NaN            NaN  St.15_GOM22SP
#
#         Distance_KM
# Sample
# 214500   147.815867
# 214501   147.815867
# 214502   147.815867
# 214503   147.815867
# 214504   147.815867
# ...             ...
# 221937    54.404978
# 221938    54.404978
# 221939    54.404978
# 2218X1    43.773728
# 2218X2    43.773728
#
# [444 rows x 12 columns]

# %%
df_locs = df_wc.groupby('code')['Depth','Site','Project'].max().reset_index()

#get WC bottom data 
grouped_data = df_wc.groupby(['code'])
sal_values = {}

for code, group in grouped_data:
    highest_row = group.loc[group['Depth'] == group['Depth'].max()]
    sal_values[code] = highest_row['Salinity'].iloc[0]

#get pw mean data 
grouped_data = df_pw.groupby(['code'])
mean_pw_values = {}

for code, group in grouped_data:
    mean_pw_values[code] = group['Salinity'].mean()
    
#get Lat mean data 
grouped_data = df_pw.groupby(['code'])
Lat_values = {}

for code, group in grouped_data:
    Lat_values[code] = group['Lat'].mean()
    
#get Lon mean data 
grouped_data = df_pw.groupby(['code'])
Lon_values = {}

for code, group in grouped_data:
    Lon_values[code] = group['Lat'].mean()
    
#get Lon mean data 
grouped_data = df_pw.groupby(['code'])
KM_values = {}

for code, group in grouped_data:
    KM_values[code] = group['Distance_KM'].mean()

# create a new column with "NA" values for all rows
df_locs['sal'] = np.nan
df_locs['pw_mean_sal'] = np.nan
df_locs['Lat'] = np.nan
df_locs['Lon'] = np.nan
df_locs['KM'] = np.nan


# create a boolean mask to select only the rows where the Station is in sal00_values
mask = df_locs['code'].isin(sal_values.keys())
mask = df_locs['code'].isin(mean_pw_values.keys())
mask = df_locs['code'].isin(Lat_values.keys())
mask = df_locs['code'].isin(Lon_values.keys())
mask = df_locs['code'].isin(KM_values.keys())

# use the mask to select only those rows and add the sal00 values to the new column
df_locs.loc[mask, 'sal'] = [sal_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'pw_mean_sal'] = [mean_pw_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'Lat'] = [Lat_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'Lon'] = [Lon_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'KM'] = [KM_values[code] for code in df_locs.loc[mask, 'code']]


df_locs = df_locs.sort_values('Depth')

#df_locs
col_order = df_locs["code"].tolist()
col_maxd = df_locs["Depth"].tolist()
col_maxd = [round(x, 1) for x in col_maxd]
col_sal = df_locs["sal"].tolist()
col_sal = [round(x, 1) for x in col_sal]
col_site = df_locs["Site"].tolist()
col_camp = df_locs["Project"].tolist()


sub_num = len(df_locs)-1
width_num = len(df_locs)

df_locs
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\3817390646.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_locs = df_wc.groupby('code')['Depth','Site','Project'].max().reset_index()
#              code       Depth   Site  Project        sal  pw_mean_sal  \
# 9    St.4_GOM21FA   16.826861   St.4  GOM21FA  31.906647    30.916667
# 14  St.MK_GOM21FA   16.950612  St.MK  GOM21FA  31.427814    33.928571
# 10   St.7_GOM21FA   38.212163   St.7  GOM21FA  36.213451    37.761905
# 7   St.16_GOM22SP   55.691592  St.16  GOM22SP  36.422288    38.000000
# 6   St.16_GOM21FA   57.745878  St.16  GOM21FA  36.291365    37.916667
# 13   St.9_GOM22SP   78.731163   St.9  GOM22SP  36.402086    39.130435
# 12   St.9_GOM21FA   80.528735   St.9  GOM21FA  36.313978    37.545455
# 3   St.14_GOM21FA   88.474469  St.14  GOM21FA  36.358073    39.117647
# 11   St.7_GOM22SP  262.737184   St.7  GOM22SP  35.533510    37.200000
# 4   St.15_GOM21FA  263.175214  St.15  GOM21FA  35.732539    38.320000
# 5   St.15_GOM22SP  263.450000  St.15  GOM22SP  35.564000    36.160000
# 2   St.13_GOM21FA  447.885344  St.13  GOM21FA  35.167441    36.958333
# 8    St.2_GOM21FA  447.885344   St.2  GOM21FA  35.167441    36.652174
# 0   St.11_GOM21FA  916.687784  St.11  GOM21FA  34.918362    36.650000
# 1   St.12_GOM21FA  950.649735  St.12  GOM21FA  34.929702    36.636364
#
#           Lat        Lon          KM
# 9   28.795860  28.795860  147.815867
# 14  28.913680  28.913680  109.183143
# 10  28.911083  28.911083   67.195205
# 7   28.917140  28.917140   39.709971
# 6   28.883543  28.883543   42.110633
# 13  28.787320  28.787320   54.404978
# 12  28.781940  28.781940   54.278145
# 3   28.911083  28.911083   67.195205
# 11  28.917240  28.917240   65.819944
# 4   28.950640  28.950640   44.491505
# 5   28.944920  28.944920   43.773728
# 2   28.522860  28.522860   78.975797
# 8   28.522860  28.522860   78.975797
# 0   28.212560  28.212560  110.203442
# 1   28.594160  28.594160   70.178478

# %%
#plot a histogram of the 'salinity' column
df_pw['Salinity'].hist(bins = 40)
plt.xlabel('PSU')
plt.ylabel('Frequency')
plt.title('PW Salinity Histogram')
# Out:
# Text(0.5, 1.0, 'PW Salinity Histogram')

# %%
#clean up the outliers 
df_pw.drop(df_pw[df_pw['Salinity'] > 50].index, inplace=True)
df_pw.drop(df_pw[df_pw['Salinity'] < 25.1].index, inplace=True)

#plot a histogram of the 'salinity' column
df_pw['Salinity'].hist(bins = 30)
plt.xlabel('PSU')
plt.ylabel('Frequency')
plt.title('PW Salinity Histogram')
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\3138580687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pw.drop(df_pw[df_pw['Salinity'] > 50].index, inplace=True)
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\3138580687.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pw.drop(df_pw[df_pw['Salinity'] < 25.1].index, inplace=True)
# Text(0.5, 1.0, 'PW Salinity Histogram')

# %%
station_vals = col_order

fig, axs = plt.subplots(nrows=1, ncols=len(station_vals), figsize=(len(station_vals)*3, 10))

for j, station_val in enumerate(station_vals):
    ax = axs[j]
    
    #get data 
    data = df_pw[(df_pw['code'] == station_val)]
        
    #get vars 
    sal = data['Salinity'] 
    sal = np.asarray(sal, dtype=float).ravel()
    
    sal_mean = sal.mean()
    sal_sd = sal.std()
    sal_mean_round = round(sal_mean, 1)

    depth = data['Depth'] #X var 
    depth = np.asarray(depth, dtype=float).ravel()
    
    #PLOT DOC
    ax.plot(sal, depth, 'o', ls='-', c='black')
    ax.set_xlim(25,50)
    ax.set_ylim(42,-1)
    ax.axhline(y=0, color='grey', linestyle='-', label='Sediment Water Interface')
    
    #plot lables 
    #Set x-axis label on bottom subplots
    ax.set_xlabel('PSU', size = 20, c='black')
    #Set y-axis label on bottom subplots
    if j == 0:
        ax.set_ylabel('Depth (cm)', size= 20)
    
    #turn off other axis
    if j != 0:
        ax.set_yticklabels([])
        
    ax.set_title(f'{col_site[j]}\n{col_camp[j]}\n Depth: {col_maxd[j]} meters', size = 20)
    ax.text(26, 40, f'Bottom Water: {col_sal[j]} PSU', size = 11)
    ax.text(26, 41, f'Mean Pore Water: {sal_mean_round} PSU', size = 11)

    
# add a global title to the figure
fig.suptitle("", size = 20)
fig.set_facecolor('w')
plt.tight_layout()

#save plot 
#plt.savefig("../../../Data_Thesis/FIGS/Pore_water_profiles/GOM2021.png")

# show the plot
plt.show()

# %%
station_vals = col_order

fig, axs = plt.subplots(nrows=1, ncols=len(station_vals), figsize=(len(station_vals)*3, 10))

for j, station_val in enumerate(station_vals):
    ax = axs[j]
    
    #get data 
    data = df_pw[(df_pw['code'] == station_val)]
        
    #get vars 
    sal = data['Salinity'] 
    sal = np.asarray(sal, dtype=float).ravel()
    
    sal_mean = sal.mean()
    sal_sd = sal.std()
    sal_mean_round = round(sal_mean, 1)

    depth = data['Depth'] #X var 
    depth = np.asarray(depth, dtype=float).ravel()
    
    #PLOT DOC
    ax.plot(sal, depth, 'o', ls='-', c='black')
    ax.set_xlim(25,50)
    ax.set_ylim(42,-1)
    ax.axhline(y=0, color='grey', linestyle='-', label='Sediment Water Interface')
    ax.axvline(x=col_sal[j], color='red', linestyle='--')
    ax.text(col_sal[j]-1.25, 30, f'Bottom water {col_sal[j]} PSU', size = 11, rotation = 90, color = 'red')
    ax.axvline(x=sal_mean, color='blue', linestyle='--')
    ax.text(sal_mean+1, 30, f'Pore water mean {col_sal[j]} PSU', size = 11, rotation = 90, color = 'blue')
    ax.axvline(x=sal_mean+sal_sd*3, color='green', linestyle='--')
    ax.text(sal_mean+sal_sd*3+1, 30, f'Pore Water PSU Standerd Dev', size = 11, rotation = 90, color = 'green')
    ax.axvline(x=sal_mean-sal_sd*3, color='green', linestyle='--')
    ax.text(sal_mean-sal_sd*3-1.25, 30, f'Pore Water PSU Standerd Dev', size = 11, rotation = 90, color = 'green')
    
    #plot lables 
    #Set x-axis label on bottom subplots
    ax.set_xlabel('PSU', size = 20, c='black')
    #Set y-axis label on bottom subplots
    if j == 0:
        ax.set_ylabel('Depth (cm)', size= 20)
    
    #turn off other axis
    if j != 0:
        ax.set_yticklabels([])
        
    ax.set_title(f'{col_site[j]}\n{col_camp[j]}\n Depth: {col_maxd[j]} meters', size = 20)
    ax.text(26, 40, f'Bottom Water: {col_sal[j]} PSU', size = 11)
    ax.text(26, 41, f'Mean Pore Water: {sal_mean_round} PSU', size = 11)

    
# add a global title to the figure
fig.suptitle("", size = 20)
fig.set_facecolor('w')
plt.tight_layout()

#save plot 
#plt.savefig("../../../Data_Thesis/FIGS/Pore_water_profiles/GOM2021.png")

# show the plot
plt.show()

# %%
station_vals = col_order

fig, axs = plt.subplots(nrows=1, ncols=len(station_vals), figsize=(len(station_vals)*3, 10))

for j, station_val in enumerate(station_vals):
    ax = axs[j]
    
    #get data 
    data = df_pw[(df_pw['code'] == station_val)]
        
    #get vars 
    sal = data['Salinity'] 
    sal = np.asarray(sal, dtype=float).ravel()
    
    sal_mean = sal.mean()
    sal_sd = sal.std()
    sal_mean_round = round(sal_mean, 1)
    
    cor_sal = data['Core_sal'] 
    cor_sal = np.asarray(cor_sal, dtype=float).ravel()
    cor_sal = cor_sal.mean()
    cor_sal_round = round(cor_sal, 1)


    depth = data['Depth'] #X var 
    depth = np.asarray(depth, dtype=float).ravel()
    
    #PLOT DOC
    ax.plot(sal, depth, 'o', ls='-', c='black')
    ax.set_xlim(25,50)
    ax.set_ylim(42,-1)
    ax.axhline(y=0, color='grey', linestyle='-', label='Sediment Water Interface')
    
    ax.axvline(x=col_sal[j], color='red', linestyle='--')
    ax.text(col_sal[j]-1.25, 30, f'Bottom water {col_sal[j]} PSU', size = 11, rotation = 90, color = 'red')
    
    ax.axvline(x=sal_mean, color='blue', linestyle='--')
    ax.text(sal_mean+1, 30, f'Pore water mean {sal_mean_round} PSU', size = 11, rotation = 90, color = 'blue')
    
    ax.axvline(x=sal_mean+sal_sd*3, color='green', linestyle='--')
    ax.text(sal_mean+sal_sd*3+1, 30, f'Pore Water PSU Standerd Dev', size = 11, rotation = 90, color = 'green')
    
    ax.axvline(x=sal_mean-sal_sd*3, color='green', linestyle='--')
    ax.text(sal_mean-sal_sd*3-1.25, 30, f'Pore Water PSU Standerd Dev', size = 11, rotation = 90, color = 'green')
    
    ax.axvline(x=cor_sal, color='purple', linestyle='--')
    ax.text(cor_sal-1, 30, f'Core Overlying water {cor_sal} PSU', size = 11, rotation = 90, color = 'blue')

    
    #plot lables 
    #Set x-axis label on bottom subplots
    ax.set_xlabel('PSU', size = 20, c='black')
    #Set y-axis label on bottom subplots
    if j == 0:
        ax.set_ylabel('Depth (cm)', size= 20)
    
    #turn off other axis
    if j != 0:
        ax.set_yticklabels([])
        
    ax.set_title(f'{col_site[j]}\n{col_camp[j]}\n Depth: {col_maxd[j]} meters', size = 20)
    ax.text(26, 40, f'Bottom Water: {col_sal[j]} PSU', size = 11)
    ax.text(26, 41, f'Mean Pore Water: {sal_mean_round} PSU', size = 11)

    
# add a global title to the figure
fig.suptitle("", size = 20)
fig.set_facecolor('w')
plt.tight_layout()

#save plot 
#plt.savefig("../../../Data_Thesis/FIGS/Pore_water_profiles/GOM2021.png")

# show the plot
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
for j, station_val in enumerate(station_vals):
    
    print(f'{col_site[j]}\n{col_camp[j]}\n Depth: {col_maxd[j]} meters\n Bottom Water: {col_sal[j]} PSU \n Mean Pore Water: {sal_mean_round} PSU')
# Out:
# St.4
# GOM21FA
#  Depth: 16.8 meters
#  Bottom Water: 31.9 PSU
#  Mean Pore Water: 36.6 PSU
# St.MK
# GOM21FA
#  Depth: 17.0 meters
#  Bottom Water: 31.4 PSU
#  Mean Pore Water: 36.6 PSU
# St.7
# GOM21FA
#  Depth: 38.2 meters
#  Bottom Water: 36.2 PSU
#  Mean Pore Water: 36.6 PSU
# St.16
# GOM22SP
#  Depth: 55.7 meters
#  Bottom Water: 36.4 PSU
#  Mean Pore Water: 36.6 PSU
# St.16
# GOM21FA
#  Depth: 57.7 meters
#  Bottom Water: 36.3 PSU
#  Mean Pore Water: 36.6 PSU
# St.9
# GOM22SP
#  Depth: 78.7 meters
#  Bottom Water: 36.4 PSU
#  Mean Pore Water: 36.6 PSU
# St.9
# GOM21FA
#  Depth: 80.5 meters
#  Bottom Water: 36.3 PSU
#  Mean Pore Water: 36.6 PSU
# St.14
# GOM21FA
#  Depth: 88.5 meters
#  Bottom Water: 36.4 PSU
#  Mean Pore Water: 36.6 PSU
# St.7
# GOM22SP
#  Depth: 262.7 meters
#  Bottom Water: 35.5 PSU
#  Mean Pore Water: 36.6 PSU
# St.15
# GOM21FA
#  Depth: 263.2 meters
#  Bottom Water: 35.7 PSU
#  Mean Pore Water: 36.6 PSU
# St.15
# GOM22SP
#  Depth: 263.4 meters
#  Bottom Water: 35.6 PSU
#  Mean Pore Water: 36.6 PSU
# St.13
# GOM21FA
#  Depth: 447.9 meters
#  Bottom Water: 35.2 PSU
#  Mean Pore Water: 36.6 PSU
# St.2
# GOM21FA
#  Depth: 447.9 meters
#  Bottom Water: 35.2 PSU
#  Mean Pore Water: 36.6 PSU
# St.11
# GOM21FA
#  Depth: 916.7 meters
#  Bottom Water: 34.9 PSU
#  Mean Pore Water: 36.6 PSU
# St.12
# GOM21FA
#  Depth: 950.6 meters
#  Bottom Water: 34.9 PSU
#  Mean Pore Water: 36.6 PSU

# %%
# Merge the DataFrames on 'code' to update 'bot_sal' in 'df'
df_merged = df_pw.merge(df_locs[['code', 'sal']], on='code', suffixes=('', '_locs'), how='left')

# Update 'bot_sal' with the values from 'sal'
sal_list = df_merged['sal'].tolist()
df_pw['bot_sal'] = sal_list

df_pw
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\1851031290.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pw['bot_sal'] = sal_list
#         Depth  Project Sample_Type  Salinity  Site       Lat        Lon  \
# Sample
# 214500  -0.20  GOM21FA          PW      33.0  St.4  28.79586 -90.702965
# 214501   0.35  GOM21FA          PW      29.0  St.4  28.79586 -90.702965
# 214502   1.05  GOM21FA          PW      30.0  St.4  28.79586 -90.702965
# 214503   1.75  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# 214504   2.45  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# ...       ...      ...         ...       ...   ...       ...        ...
# 221919  22.20  GOM22SP          PW      45.0  St.9  28.78732 -89.609723
# 221920  24.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221921  27.70  GOM22SP          PW      44.0  St.9  28.78732 -89.609723
# 221922  30.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221923  33.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
#
#         Sed_density  Core_sal  water_density          code  Distance_KM  \
# Sample
# 214500         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214501         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214502         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214503         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214504         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# ...             ...       ...            ...           ...          ...
# 221919         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221920         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221921         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221922         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221923         2.65      35.0          1.035  St.9_GOM22SP    54.404978
#
#           bot_sal
# Sample
# 214500  31.906647
# 214501  31.906647
# 214502  31.906647
# 214503  31.906647
# 214504  31.906647
# ...           ...
# 221919  36.402086
# 221920  36.402086
# 221921  36.402086
# 221922  36.402086
# 221923  36.402086
#
# [299 rows x 13 columns]

# %%
# Merge the DataFrames on 'code' to update 'pw_mean_sal' in 'df'
df_merged = df_pw.merge(df_locs[['code', 'pw_mean_sal']], on='code', suffixes=('', '_locs'), how='left')

# Update 'bot_sal' with the values from 'sal'
pw_mean_list = df_merged['pw_mean_sal'].tolist()
df_pw['pw_mean_sal'] = pw_mean_list

df_pw
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\631275096.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pw['pw_mean_sal'] = pw_mean_list
#         Depth  Project Sample_Type  Salinity  Site       Lat        Lon  \
# Sample
# 214500  -0.20  GOM21FA          PW      33.0  St.4  28.79586 -90.702965
# 214501   0.35  GOM21FA          PW      29.0  St.4  28.79586 -90.702965
# 214502   1.05  GOM21FA          PW      30.0  St.4  28.79586 -90.702965
# 214503   1.75  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# 214504   2.45  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# ...       ...      ...         ...       ...   ...       ...        ...
# 221919  22.20  GOM22SP          PW      45.0  St.9  28.78732 -89.609723
# 221920  24.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221921  27.70  GOM22SP          PW      44.0  St.9  28.78732 -89.609723
# 221922  30.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221923  33.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
#
#         Sed_density  Core_sal  water_density          code  Distance_KM  \
# Sample
# 214500         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214501         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214502         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214503         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214504         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# ...             ...       ...            ...           ...          ...
# 221919         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221920         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221921         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221922         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221923         2.65      35.0          1.035  St.9_GOM22SP    54.404978
#
#           bot_sal  pw_mean_sal
# Sample
# 214500  31.906647    30.916667
# 214501  31.906647    30.916667
# 214502  31.906647    30.916667
# 214503  31.906647    30.916667
# 214504  31.906647    30.916667
# ...           ...          ...
# 221919  36.402086    39.130435
# 221920  36.402086    39.130435
# 221921  36.402086    39.130435
# 221922  36.402086    39.130435
# 221923  36.402086    39.130435
#
# [299 rows x 14 columns]

# %%
# Merge the DataFrames on 'code' to update 'WaterDepth' in 'df'
df_merged = df_pw.merge(df_locs[['code', 'Depth']], on='code', suffixes=('', '_locs'), how='left')

# Update 'bot_sal' with the values from 'sal'
pw_mean_list = df_merged['Depth_locs'].tolist()
df_pw['WC_depth'] = pw_mean_list

df_pw
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\4207041744.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pw['WC_depth'] = pw_mean_list
#         Depth  Project Sample_Type  Salinity  Site       Lat        Lon  \
# Sample
# 214500  -0.20  GOM21FA          PW      33.0  St.4  28.79586 -90.702965
# 214501   0.35  GOM21FA          PW      29.0  St.4  28.79586 -90.702965
# 214502   1.05  GOM21FA          PW      30.0  St.4  28.79586 -90.702965
# 214503   1.75  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# 214504   2.45  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# ...       ...      ...         ...       ...   ...       ...        ...
# 221919  22.20  GOM22SP          PW      45.0  St.9  28.78732 -89.609723
# 221920  24.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221921  27.70  GOM22SP          PW      44.0  St.9  28.78732 -89.609723
# 221922  30.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 221923  33.70  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
#
#         Sed_density  Core_sal  water_density          code  Distance_KM  \
# Sample
# 214500         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214501         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214502         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214503         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 214504         2.65      31.0          1.031  St.4_GOM21FA   147.815867
# ...             ...       ...            ...           ...          ...
# 221919         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221920         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221921         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221922         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 221923         2.65      35.0          1.035  St.9_GOM22SP    54.404978
#
#           bot_sal  pw_mean_sal   WC_depth
# Sample
# 214500  31.906647    30.916667  16.826861
# 214501  31.906647    30.916667  16.826861
# 214502  31.906647    30.916667  16.826861
# 214503  31.906647    30.916667  16.826861
# 214504  31.906647    30.916667  16.826861
# ...           ...          ...        ...
# 221919  36.402086    39.130435  78.731163
# 221920  36.402086    39.130435  78.731163
# 221921  36.402086    39.130435  78.731163
# 221922  36.402086    39.130435  78.731163
# 221923  36.402086    39.130435  78.731163
#
# [299 rows x 15 columns]

# %%
# Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
    
# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal']):
# Prepare the data for the subplot
    data = df_pw[[x_var, 'Salinity']]
    data.dropna(inplace=True)
    X = data[[x_var]]
    y = data['Salinity']
        
    # Fit a linear regression model to the data
    model = LinearRegression()
    model.fit(X, y)
    score = model.score(X, y)
        
    # Plot the data and regression line
    ax = axes[i]
    sns.scatterplot(x=x_var, y='Salinity', data=data, ax=ax, legend=False)
    sns.lineplot(x=X[x_var], y=model.predict(X), ax=ax, color='black')
        
    # Set the axis labels and title
    ax.set_xlabel(x_var.replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size = 15)
    if i == 0: 
        ax.set_ylabel('Salinity PSU', size = 15)
    else: 
        ax.set_ylabel('')
    ax.set_title(f'R\u00B2: {score:.2f}', size = 20, color = 'red')
    ax.set_ylim([data['Salinity'].min(), data['Salinity'].max()])
    ax.set_xlim([data[x_var].min(), data[x_var].max()])
            
# Adjust the layout of the subplots
fig.suptitle(f'', size = 20)
fig.set_facecolor('w')
plt.tight_layout()
    
#plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\2168272484.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\2168272484.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
# Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal']):
    # Prepare the data for the subplot
    data = df_pw[[x_var, 'Salinity', 'Project']]
    data.dropna(inplace=True)
    X = data[[x_var]]
    y = data['Salinity']

    # Fit a linear regression model to the data
    model = LinearRegression()
    model.fit(X, y)
    score = model.score(X, y)

    # Plot the data and regression line
    ax = axes[i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Project', data=data, ax=ax, legend=False)
    sns.lineplot(x=X[x_var], y=model.predict(X), ax=ax, color='black')

    # Set the axis labels and title
    ax.set_xlabel(x_var.replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size=15)
    if i == 0:
        ax.set_ylabel('Salinity PSU', size=15)
    else:
        ax.set_ylabel('')
    ax.set_title(f'R\u00B2: {score:.2f}', size=20, color='red')
    ax.set_ylim([data['Salinity'].min(), data['Salinity'].max()])
    ax.set_xlim([data[x_var].min(), data[x_var].max()])

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

# plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\224125448.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\224125448.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
# Create a new plot with 2 rows and 2 columns
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))

# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal']):
    # Prepare the data for the subplot
    data_gom22sp = df_pw[df_pw['Project'] == 'GOM22SP'][[x_var, 'Salinity', 'Site']]
    data_gom21fa = df_pw[df_pw['Project'] == 'GOM21FA'][[x_var, 'Salinity', 'Site']]

    data_gom22sp.dropna(inplace=True)
    data_gom21fa.dropna(inplace=True)

    X_gom22sp = data_gom22sp[[x_var]]
    y_gom22sp = data_gom22sp['Salinity']

    X_gom21fa = data_gom21fa[[x_var]]
    y_gom21fa = data_gom21fa['Salinity']

    # Fit linear regression models to the data
    model_gom22sp = LinearRegression()
    model_gom22sp.fit(X_gom22sp, y_gom22sp)
    score_gom22sp = model_gom22sp.score(X_gom22sp, y_gom22sp)

    model_gom21fa = LinearRegression()
    model_gom21fa.fit(X_gom21fa, y_gom21fa)
    score_gom21fa = model_gom21fa.score(X_gom21fa, y_gom21fa)

    # Plot the data and regression line for GOM22SP
    ax = axes[0, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Site', data=data_gom22sp, ax=ax, legend='brief')
    sns.lineplot(x=X_gom22sp[x_var], y=model_gom22sp.predict(X_gom22sp), ax=ax, color='black')

    # Plot the data and regression line for GOM21FA
    ax = axes[1, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Site', data=data_gom21fa, ax=ax, legend='brief')
    sns.lineplot(x=X_gom21fa[x_var], y=model_gom21fa.predict(X_gom21fa), ax=ax, color='black')

    # Set the axis labels and title for GOM22SP
    if i == 0:
        axes[0, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[0, i].set_ylabel('')
    axes[0, i].set_title(f'R\u00B2 (GOM22SP): {score_gom22sp:.2f}', size=15, color='red')
    axes[0, i].set_ylim([data_gom22sp['Salinity'].min(), data_gom22sp['Salinity'].max()])
    axes[0, i].set_xlim([data_gom22sp[x_var].min(), data_gom22sp[x_var].max()])

    # Set the axis labels and title for GOM21FA
    axes[1, i].set_xlabel(x_var.replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size=15)
    if i == 0:
        axes[1, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[1, i].set_ylabel('')
    axes[1, i].set_title(f'R\u00B2 (GOM21FA): {score_gom21fa:.2f}', size=15, color='red')
    axes[1, i].set_ylim([data_gom21fa['Salinity'].min(), data_gom21fa['Salinity'].max()])
    axes[1, i].set_xlim([data_gom21fa[x_var].min(), data_gom21fa[x_var].max()])

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

# plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()

# %%
# Create a new plot with 2 rows and 2 columns
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))

# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal']):
    # Prepare the data for the subplot
    data_gom22sp = df_pw[df_pw['Project'] == 'GOM22SP'][[x_var, 'Salinity', 'Distance_KM']]
    data_gom21fa = df_pw[df_pw['Project'] == 'GOM21FA'][[x_var, 'Salinity', 'Distance_KM']]

    data_gom22sp.dropna(inplace=True)
    data_gom21fa.dropna(inplace=True)

    X_gom22sp = data_gom22sp[[x_var]]
    y_gom22sp = data_gom22sp['Salinity']

    X_gom21fa = data_gom21fa[[x_var]]
    y_gom21fa = data_gom21fa['Salinity']

    # Fit linear regression models to the data
    model_gom22sp = LinearRegression()
    model_gom22sp.fit(X_gom22sp, y_gom22sp)
    score_gom22sp = model_gom22sp.score(X_gom22sp, y_gom22sp)

    model_gom21fa = LinearRegression()
    model_gom21fa.fit(X_gom21fa, y_gom21fa)
    score_gom21fa = model_gom21fa.score(X_gom21fa, y_gom21fa)

    # Plot the data and regression line for GOM22SP
    ax = axes[0, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Distance_KM', data=data_gom22sp, ax=ax, legend='brief')
    sns.lineplot(x=X_gom22sp[x_var], y=model_gom22sp.predict(X_gom22sp), ax=ax, color='black')

    # Plot the data and regression line for GOM21FA
    ax = axes[1, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Distance_KM', data=data_gom21fa, ax=ax, legend='brief')
    sns.lineplot(x=X_gom21fa[x_var], y=model_gom21fa.predict(X_gom21fa), ax=ax, color='black')

    # Set the axis labels and title for GOM22SP
    if i == 0:
        axes[0, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[0, i].set_ylabel('')
    axes[0, i].set_title(f'R\u00B2 (GOM22SP): {score_gom22sp:.2f}', size=15, color='red')
    axes[0, i].set_ylim([data_gom22sp['Salinity'].min(), data_gom22sp['Salinity'].max()])
    axes[0, i].set_xlim([data_gom22sp[x_var].min(), data_gom22sp[x_var].max()])

    # Set the axis labels and title for GOM21FA
    axes[1, i].set_xlabel(x_var.replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size=15)
    if i == 0:
        axes[1, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[1, i].set_ylabel('')
    axes[1, i].set_title(f'R\u00B2 (GOM21FA): {score_gom21fa:.2f}', size=15, color='red')
    axes[1, i].set_ylim([data_gom21fa['Salinity'].min(), data_gom21fa['Salinity'].max()])
    axes[1, i].set_xlim([data_gom21fa[x_var].min(), data_gom21fa[x_var].max()])

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

# plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()

# %%
# Set up the color bar limits
vmin = df_pw['Distance_KM'].min()
vmax = df_pw['Distance_KM'].max()

# Create a new plot with 2 rows and 2 columns
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))

# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal']):
    # Prepare the data for the subplot
    data_gom22sp = df_pw[df_pw['Project'] == 'GOM22SP'][[x_var, 'Salinity', 'Distance_KM']]
    data_gom21fa = df_pw[df_pw['Project'] == 'GOM21FA'][[x_var, 'Salinity', 'Distance_KM']]

    data_gom22sp.dropna(inplace=True)
    data_gom21fa.dropna(inplace=True)

    X_gom22sp = data_gom22sp[[x_var]]
    y_gom22sp = data_gom22sp['Salinity']
    colors_gom22sp = data_gom22sp['Distance_KM']


    X_gom21fa = data_gom21fa[[x_var]]
    y_gom21fa = data_gom21fa['Salinity']
    colors_gom21fa = data_gom21fa['Distance_KM']


    # Fit linear regression models to the data
    model_gom22sp = LinearRegression()
    model_gom22sp.fit(X_gom22sp, y_gom22sp)
    score_gom22sp = model_gom22sp.score(X_gom22sp, y_gom22sp)

    model_gom21fa = LinearRegression()
    model_gom21fa.fit(X_gom21fa, y_gom21fa)
    score_gom21fa = model_gom21fa.score(X_gom21fa, y_gom21fa)

    # Plot the data and regression line for GOM22SP
    ax = axes[0, i]
    sns.scatterplot(x=x_var, y='Salinity',c=colors_gom22sp, cmap=cmo.deep, vmin=vmin, vmax=vmax, legend=False,
                    data=data_gom22sp, ax=ax)
    sns.lineplot(x=X_gom22sp[x_var], y=model_gom22sp.predict(X_gom22sp), ax=ax, color='black')

    # Plot the data and regression line for GOM21FA
    ax = axes[1, i]
    sns.scatterplot(x=x_var, y='Salinity',c=colors_gom21fa, cmap=cmo.deep, vmin=vmin, vmax=vmax,
                    data=data_gom21fa, ax=ax, legend=False)
    sns.lineplot(x=X_gom21fa[x_var], y=model_gom21fa.predict(X_gom21fa), ax=ax, color='black')

    # Set the axis labels and title for GOM22SP
    if i == 0:
        axes[0, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[0, i].set_ylabel('')
    axes[0, i].set_title(f'R\u00B2 (GOM22SP): {score_gom22sp:.2f}', size=15, color='red')
    axes[0, i].set_ylim([data_gom22sp['Salinity'].min(), data_gom22sp['Salinity'].max()])
    axes[0, i].set_xlim([data_gom22sp[x_var].min(), data_gom22sp[x_var].max()])

    # Set the axis labels and title for GOM21FA
    axes[1, i].set_xlabel(x_var.replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size=15)
    if i == 0:
        axes[1, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[1, i].set_ylabel('')
    axes[1, i].set_title(f'R\u00B2 (GOM21FA): {score_gom21fa:.2f}', size=15, color='red')
    axes[1, i].set_ylim([data_gom21fa['Salinity'].min(), data_gom21fa['Salinity'].max()])
    axes[1, i].set_xlim([data_gom21fa[x_var].min(), data_gom21fa[x_var].max()])

# Add a color bar for the depth on the right side of the figure
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([.9, 0.15, 0.03, 0.7])
cbar = fig.colorbar(plt.cm.ScalarMappable(cmap=cmo.deep, norm=plt.Normalize(vmin=vmin, vmax=vmax)), cax=cbar_ax)
cbar.ax.set_ylabel('Distance from Missisppi KM', size = 20)

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
#plt.tight_layout()

# plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()

# %%
# Create a new plot with 2 rows and 2 columns
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

# Loop through the subplots
for i, x_var in enumerate(['Depth', 'bot_sal', 'Distance_KM']):
    # Prepare the data for the subplot
    data_gom22sp = df_pw[df_pw['Project'] == 'GOM22SP'][[x_var, 'Salinity', 'Site']]
    data_gom21fa = df_pw[df_pw['Project'] == 'GOM21FA'][[x_var, 'Salinity', 'Site']]

    data_gom22sp.dropna(inplace=True)
    data_gom21fa.dropna(inplace=True)

    X_gom22sp = data_gom22sp[[x_var]]
    y_gom22sp = data_gom22sp['Salinity']

    X_gom21fa = data_gom21fa[[x_var]]
    y_gom21fa = data_gom21fa['Salinity']

    # Fit linear regression models to the data
    model_gom22sp = LinearRegression()
    model_gom22sp.fit(X_gom22sp, y_gom22sp)
    score_gom22sp = model_gom22sp.score(X_gom22sp, y_gom22sp)

    model_gom21fa = LinearRegression()
    model_gom21fa.fit(X_gom21fa, y_gom21fa)
    score_gom21fa = model_gom21fa.score(X_gom21fa, y_gom21fa)

    # Plot the data and regression line for GOM22SP
    ax = axes[0, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Site', data=data_gom22sp, ax=ax, legend='brief')
    sns.lineplot(x=X_gom22sp[x_var], y=model_gom22sp.predict(X_gom22sp), ax=ax, color='black')

    # Plot the data and regression line for GOM21FA
    ax = axes[1, i]
    sns.scatterplot(x=x_var, y='Salinity', hue='Site', data=data_gom21fa, ax=ax, legend='brief')
    sns.lineplot(x=X_gom21fa[x_var], y=model_gom21fa.predict(X_gom21fa), ax=ax, color='black')

    # Set the axis labels and title for GOM22SP
    if i == 0:
        axes[0, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[0, i].set_ylabel('')
    axes[0, i].set_title(f'R\u00B2 (GOM22SP): {score_gom22sp:.2f}', size=15, color='red')
    axes[0, i].set_ylim([data_gom22sp['Salinity'].min(), data_gom22sp['Salinity'].max()])
    axes[0, i].set_xlim([data_gom22sp[x_var].min(), data_gom22sp[x_var].max()])

    # Set the axis labels and title for GOM21FA
    axes[1, i].set_xlabel(x_var.replace('Distance_KM', 'Distance from Missisppi KM').replace('Depth', 'Depth (cm)').replace('bot_sal', 'Bottom water salinity'), size=15)
    if i == 0:
        axes[1, i].set_ylabel('Salinity PSU', size=15)
    else:
        axes[1, i].set_ylabel('')
    axes[1, i].set_title(f'R\u00B2 (GOM21FA): {score_gom21fa:.2f}', size=15, color='red')
    axes[1, i].set_ylim([data_gom21fa['Salinity'].min(), data_gom21fa['Salinity'].max()])
    axes[1, i].set_xlim([data_gom21fa[x_var].min(), data_gom21fa[x_var].max()])

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

# plt.savefig(f"../../../Data_Thesis/FIGS/Cor_plots/PW_cor_breakdown/FE_DOC_{station}.png")
plt.show()

# %%
# Assuming you have a DataFrame called 'df_locs' containing the columns 'sal' and 'pw_mean_sal'

# Step 1: Prepare the data
X = df_locs["sal"].values.reshape(-1, 1)
y = df_locs["pw_mean_sal"].values

# Step 2: Train the regression model
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_sal = model.coef_[0]
intercept = model.intercept_

# Step 4: Make predictions on the original data
y_pred = model.predict(X)

# Step 5: Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

# Plot the data and regression line
ax = axes
sns.scatterplot(x=X.ravel(), y=y, legend=False)
sns.lineplot(x=X.ravel(), y=y_pred, ax=ax, color='black')

# Set the axis labels and title
ax.set_xlabel("Bottom Water Salinity PSU", size=15)
ax.set_ylabel('Mean Pore Pater Salinity PSU', size=15)
ax.set_title(f'R\u00B2: {score:.2f}', size=20, color='red')

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

plt.show()

# %%
# Assuming you have a DataFrame called 'df_locs' containing the columns 'sal' and 'pw_mean_sal'

# Step 1: Prepare the data
X = df_locs["KM"].values.reshape(-1, 1)
y = df_locs["pw_mean_sal"].values

# Step 2: Train the regression model
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_sal = model.coef_[0]
intercept = model.intercept_

# Step 4: Make predictions on the original data
y_pred = model.predict(X)

# Step 5: Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

# Plot the data and regression line
ax = axes
sns.scatterplot(x=X.ravel(), y=y, legend=False)
sns.lineplot(x=X.ravel(), y=y_pred, ax=ax, color='black')

# Set the axis labels and title
ax.set_xlabel("Distance from Missisppi KM", size=15)
ax.set_ylabel('Mean Pore Pater Salinity PSU', size=15)
ax.set_title(f'R\u00B2: {score:.2f}', size=20, color='red')

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

plt.show()

# %%
#regression 

# Step 1: Prepare the data
X = df_pw[['bot_sal', 'Distance_KM']]  # Features ('bot_sal' and 'Depth')
y = df_pw['pw_mean_sal']  # Target variable

# Step 2: Train the regression model
reg_model = LinearRegression()
reg_model.fit(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_bot_sal, coef_dist = reg_model.coef_
intercept = reg_model.intercept_

# Step 4: Make predictions on the original data
y_pred = reg_model.predict(X)

# Step 5: Visualize the regression line with the actual data points
plt.scatter(X['bot_sal'], y, color='blue', label='Actual Data')
plt.plot(X['bot_sal'], y_pred, color='red', label='Regression Line')
plt.xlabel('Bottom Water Salinity')
plt.ylabel('Mean Pore Water Salinity')
plt.legend()
plt.title('Regression Model: Mean Pore Water Salinity Prediction')
plt.show()

# Step 6: Print the equation of the regression line
print(f"Salinity = {coef_bot_sal:.2f} * bot_sal + {coef_dist:.2f} * Distance + {intercept:.2f}")
# Out:
# Salinity = 1.09 * bot_sal + -0.01 * Distance + -1.04

# %%
#regression 

# Step 1: Prepare the data
X = df_pw[['bot_sal']]  # Features ('bot_sal' and 'Depth')
y = df_pw['Salinity']  # Target variable

# Step 2: Train the regression model
reg_model = LinearRegression()
reg_model.fit(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_bot_sal, = reg_model.coef_
intercept = reg_model.intercept_

# Step 4: Make predictions on the original data
y_pred = reg_model.predict(X)

# Step 5: Visualize the regression line with the actual data points
plt.scatter(X['bot_sal'], y, color='blue', label='Actual Data')
plt.plot(X['bot_sal'], y_pred, color='red', label='Regression Line')
plt.xlabel('bot_sal')
plt.ylabel('Salinity')
plt.legend()
plt.title('Regression Model: Salinity Prediction')
plt.show()

# Step 6: Print the equation of the regression line
print(f"Salinity = {coef_bot_sal:.2f} * bot_sal + {intercept:.2f}")
# Out:
# Salinity = 1.11 * bot_sal + -2.34

# %%
from scipy.interpolate import pchip_interpolate

df_por = pd.read_csv('../../../Data_Thesis/Porosity/Porosity.csv', sep=',', index_col=0)

df_por['code'] = df_por['Stn'] + '_' + df_por['camp']
df_por = df_por[df_por['code'].isin(unique_codes)]
df_por['Depth'] = df_por['depth'].astype(float)
df_por['porosity'] = df_por['porosity'].astype(float)

df_por
# Out:
#      porosity depth     camp    Stn           code  Depth
# 230  0.926658  0.25  GOM21FA  St.11  St.11_GOM21FA   0.25
# 231  0.905162  0.75  GOM21FA  St.11  St.11_GOM21FA   0.75
# 232  0.905085  1.25  GOM21FA  St.11  St.11_GOM21FA   1.25
# 233  0.894661  1.75  GOM21FA  St.11  St.11_GOM21FA   1.75
# 234  0.890890  2.25  GOM21FA  St.11  St.11_GOM21FA   2.25
# ..        ...   ...      ...    ...            ...    ...
# 716  0.741891  40.0  GOM22SP   St.9   St.9_GOM22SP  40.00
# 717  0.749684  44.0  GOM22SP   St.9   St.9_GOM22SP  44.00
# 718  0.730318  48.0  GOM22SP   St.9   St.9_GOM22SP  48.00
# 719  0.756712  52.0  GOM22SP   St.9   St.9_GOM22SP  52.00
# 720  0.746002  56.0  GOM22SP   St.9   St.9_GOM22SP  56.00
#
# [335 rows x 6 columns]

# %%
unique_codes2 = df_por['code'].unique().tolist()
my_list = list(range(len(unique_codes2)))

for x in my_list: 
    # Get the corresponding group from df_por based on 'code'
    porosity_group = df_por[df_por['code'] == unique_codes2[x]]
    pw_group = df_pw[df_pw['code'] == unique_codes2[x]]
    #pw_group = pw_group.drop(pw_group[pw_group['Depth'] < 0].index)
    
    X_por = np.asarray(porosity_group['porosity'], dtype=float).ravel()
    Y_dep = np.asarray(porosity_group['Depth'], dtype=float).ravel()
    Z_dep = np.asarray(pw_group['Depth'], dtype=float).ravel()
    
    # Create an interpolation function based on the 'Depth' and 'porosity' columns
    interp_func = pchip_interpolate(Y_dep, X_por, Z_dep)
    
    # Create a plot
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.plot(interp_func, Z_dep, marker='o', linestyle='-', color='blue')
    ax1.set_xlabel('interp_func')
    ax1.set_ylabel('Depth', color='blue')
    ax1.set_ylim(40,-1)
    ax1.tick_params(axis='y', labelcolor='blue')
    ax1.set_title('Depth salinity')
    
    # Create a second y-axis (right y-axis) and plot Y_dep against X_por on it
    ax2 = ax1.twinx()
    ax2.plot(X_por, Y_dep, marker='x', linestyle='--', color='red')
    ax2.set_ylim(40,-1)
    ax2.set_ylabel('Depth Porosity', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
# Initialize an empty DataFrame to store the integrated data
integrated_df = pd.DataFrame(columns=['code', 'Depth', 'porosity'])

for x in my_list: 
    # Get the corresponding group from df_por based on 'code'
    porosity_group = df_por[df_por['code'] == unique_codes2[x]]
    pw_group = df_pw[df_pw['code'] == unique_codes2[x]]
    #pw_group = pw_group.drop(pw_group[pw_group['Depth'] < 0].index)
    
    X_por = np.asarray(porosity_group['porosity'], dtype=float).ravel()
    Y_dep = np.asarray(porosity_group['Depth'], dtype=float).ravel()
    Z_dep = np.asarray(pw_group['Depth'], dtype=float).ravel()
    
    # Create an interpolation function based on the 'Depth' and 'porosity' columns
    interp_porosity = pchip_interpolate(Y_dep, X_por, Z_dep)

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import pchip_interpolate

# Assuming you have the DataFrame df_por and df_pw as described in the previous code snippet
# Assuming my_list, unique_codes2, and interp_porosity are defined as shown in the previous code snippet

# Initialize an empty DataFrame to store the integrated data
integrated_df = pd.DataFrame(columns=['code', 'Depth', 'porosity'])

for x in my_list:
    # Get the corresponding group from df_por based on 'code'
    porosity_group = df_por[df_por['code'] == unique_codes2[x]]
    pw_group = df_pw[df_pw['code'] == unique_codes2[x]]
    
    # Drop rows in pw_group where 'Depth' is less than 0
    pw_group = pw_group.drop(pw_group[pw_group['Depth'] < 0].index)
    
    X_por = np.asarray(porosity_group['porosity'], dtype=float).ravel()
    Y_dep = np.asarray(porosity_group['Depth'], dtype=float).ravel()
    Z_dep = np.asarray(pw_group['Depth'], dtype=float).ravel()
    
    # Create an interpolation function based on the 'Depth' and 'porosity' columns
    interp_porosity = pchip_interpolate(Y_dep, X_por, Z_dep)
    
    # Create a DataFrame to store the interpolated data
    interpolated_data = pd.DataFrame({
        'code': unique_codes2[x],
        'Depth': Z_dep,
        'porosity': interp_porosity
    })
    
    # Append the interpolated data to the integrated DataFrame
    integrated_df = pd.concat([integrated_df, interpolated_data], ignore_index=True)

# Now, integrated_df contains the interpolated data matched to the corresponding 'code' and 'Depth' values
df_pw = pd.merge(df_pw, integrated_df, on=['code', 'Depth'], how='left')
df_pw
# Out:
#     Depth  Project Sample_Type  Salinity  Site       Lat        Lon  \
# 0    -0.2  GOM21FA          PW      33.0  St.4  28.79586 -90.702965
# 1    0.35  GOM21FA          PW      29.0  St.4  28.79586 -90.702965
# 2    1.05  GOM21FA          PW      30.0  St.4  28.79586 -90.702965
# 3    1.75  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# 4    2.45  GOM21FA          PW      31.0  St.4  28.79586 -90.702965
# ..    ...      ...         ...       ...   ...       ...        ...
# 294  22.2  GOM22SP          PW      45.0  St.9  28.78732 -89.609723
# 295  24.7  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 296  27.7  GOM22SP          PW      44.0  St.9  28.78732 -89.609723
# 297  30.7  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
# 298  33.7  GOM22SP          PW      38.0  St.9  28.78732 -89.609723
#
#      Sed_density  Core_sal  water_density          code  Distance_KM  \
# 0           2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 1           2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 2           2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 3           2.65      31.0          1.031  St.4_GOM21FA   147.815867
# 4           2.65      31.0          1.031  St.4_GOM21FA   147.815867
# ..           ...       ...            ...           ...          ...
# 294         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 295         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 296         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 297         2.65      35.0          1.035  St.9_GOM22SP    54.404978
# 298         2.65      35.0          1.035  St.9_GOM22SP    54.404978
#
#        bot_sal  pw_mean_sal   WC_depth  porosity
# 0    31.906647    30.916667  16.826861       NaN
# 1    31.906647    30.916667  16.826861  0.761508
# 2    31.906647    30.916667  16.826861  0.755892
# 3    31.906647    30.916667  16.826861  0.755741
# 4    31.906647    30.916667  16.826861  0.632038
# ..         ...          ...        ...       ...
# 294  36.402086    39.130435  78.731163  0.699533
# 295  36.402086    39.130435  78.731163  0.683211
# 296  36.402086    39.130435  78.731163  0.707151
# 297  36.402086    39.130435  78.731163  0.713902
# 298  36.402086    39.130435  78.731163  0.728113
#
# [299 rows x 16 columns]

# %%
# Assuming you have a DataFrame called 'df_locs' containing the columns 'sal' and 'pw_mean_sal'

pw_plot = df_pw.dropna(subset=['porosity'])

# Step 1: Prepare the data
X = pw_plot["Salinity"].values.reshape(-1, 1)
y = pw_plot["porosity"].values

# Step 2: Train the regression model
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_sal = model.coef_[0]
intercept = model.intercept_

# Step 4: Make predictions on the original data
y_pred = model.predict(X)

# Step 5: Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

# Plot the data and regression line
ax = axes
sns.scatterplot(x=X.ravel(), y=y, legend=False)
sns.lineplot(x=X.ravel(), y=y_pred, ax=ax, color='black')

# Set the axis labels and title
ax.set_xlabel("Salinity PSU", size=15)
ax.set_ylabel('Porosity', size=15)
ax.set_title(f'R\u00B2: {score:.2f}', size=20, color='red')

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

plt.show()

# %%
df_pw.to_csv('../../../Data_Thesis/Meta_data/PW_sal_stats.csv')
df_locs.to_csv('../../../Data_Thesis/Meta_data/mean_sal_stats.csv')

# %%
STOP HERE
# Out:
#   Input In [34]
#     STOP HERE
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# GO TO R AND RUN IT

# %%
df_r = pd.read_csv('../../../Data_Thesis/Meta_data/R_pw_sal_export.csv', sep=',', index_col=0)
df_r
# Out:
#      Depth  Project Sample_Type  Salinity  Site       Lat        Lon  \
# X
# 1     0.35  GOM21FA          PW        29  St.4  28.79586 -90.702965
# 2     1.05  GOM21FA          PW        30  St.4  28.79586 -90.702965
# 3     1.75  GOM21FA          PW        31  St.4  28.79586 -90.702965
# 4     2.45  GOM21FA          PW        31  St.4  28.79586 -90.702965
# 5     3.15  GOM21FA          PW        31  St.4  28.79586 -90.702965
# ..     ...      ...         ...       ...   ...       ...        ...
# 294  22.20  GOM22SP          PW        45  St.9  28.78732 -89.609723
# 295  24.70  GOM22SP          PW        38  St.9  28.78732 -89.609723
# 296  27.70  GOM22SP          PW        44  St.9  28.78732 -89.609723
# 297  30.70  GOM22SP          PW        38  St.9  28.78732 -89.609723
# 298  33.70  GOM22SP          PW        38  St.9  28.78732 -89.609723
#
#      Sed_density  Core_sal  water_density          code  Distance_KM  \
# X
# 1           2.65        31          1.031  St.4_GOM21FA   147.815867
# 2           2.65        31          1.031  St.4_GOM21FA   147.815867
# 3           2.65        31          1.031  St.4_GOM21FA   147.815867
# 4           2.65        31          1.031  St.4_GOM21FA   147.815867
# 5           2.65        31          1.031  St.4_GOM21FA   147.815867
# ..           ...       ...            ...           ...          ...
# 294         2.65        35          1.035  St.9_GOM22SP    54.404978
# 295         2.65        35          1.035  St.9_GOM22SP    54.404978
# 296         2.65        35          1.035  St.9_GOM22SP    54.404978
# 297         2.65        35          1.035  St.9_GOM22SP    54.404978
# 298         2.65        35          1.035  St.9_GOM22SP    54.404978
#
#        bot_sal  pw_mean_sal   WC_depth  porosity        fit        lwr  \
# X
# 1    31.906647    30.916667  16.826861  0.761508  31.677686  27.524964
# 2    31.906647    30.916667  16.826861  0.755892  31.666302  27.515417
# 3    31.906647    30.916667  16.826861  0.755741  31.688370  27.536936
# 4    31.906647    30.916667  16.826861  0.632038  31.236707  27.079419
# 5    31.906647    30.916667  16.826861  0.500841  30.946899  26.667397
# ..         ...          ...        ...       ...        ...        ...
# 294  36.402086    39.130435  78.731163  0.699533  39.033585  34.946054
# 295  36.402086    39.130435  78.731163  0.683211  39.590692  35.460570
# 296  36.402086    39.130435  78.731163  0.707151  39.367261  35.255957
# 297  36.402086    39.130435  78.731163  0.713902  39.443176  35.321125
# 298  36.402086    39.130435  78.731163  0.728113  39.255418  35.136948
#
#            upr
# X
# 1    35.830409
# 2    35.817186
# 3    35.839805
# 4    35.393994
# 5    35.226400
# ..         ...
# 294  43.121117
# 295  43.720814
# 296  43.478565
# 297  43.565228
# 298  43.373888
#
# [242 rows x 19 columns]

# %%
# Assuming you have a DataFrame called 'df_locs' containing the columns 'sal' and 'pw_mean_sal'

# Step 1: Prepare the data
X = df_r["Salinity"].values.reshape(-1, 1)
y = df_r["fit"].values

# Step 2: Train the regression model
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)

# Step 3: Get the coefficients and intercept from the model
coef_sal = model.coef_[0]
intercept = model.intercept_

# Step 4: Make predictions on the original data
y_pred = model.predict(X)

# Step 5: Create a new plot for each group
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

# Plot the data and regression line
ax = axes
sns.scatterplot(x=X.ravel(), y=y, legend=False)
sns.lineplot(x=X.ravel(), y=y_pred, ax=ax, color='black')

# Set the axis labels and title
ax.set_xlabel("Mesured PW", size=15)
ax.set_ylabel('Varable Calcuated PW', size=15)
ax.set_title(f'R\u00B2: {score:.2f}', size=20, color='red')

# Adjust the layout of the subplots
fig.suptitle(f'', size=20)
fig.set_facecolor('w')
plt.tight_layout()

plt.show()

# %%
df_locs = df_r.groupby('code')['Site','Project'].max().reset_index()

#get WC bottom data 
grouped_data = df_wc.groupby(['code'])
sal_values = {}

for code, group in grouped_data:
    highest_row = group.loc[group['Depth'] == group['Depth'].max()]
    sal_values[code] = highest_row['Salinity'].iloc[0]

#get pw mean data 
grouped_data = df_pw.groupby(['code'])
mean_pw_values = {}

for code, group in grouped_data:
    mean_pw_values[code] = group['Salinity'].mean()
    
#get Lat mean data 
grouped_data = df_pw.groupby(['code'])
Lat_values = {}

for code, group in grouped_data:
    Lat_values[code] = group['Lat'].mean()
    
#get Lon mean data 
grouped_data = df_pw.groupby(['code'])
Lon_values = {}

for code, group in grouped_data:
    Lon_values[code] = group['Lat'].mean()
    
#get Lon mean data 
grouped_data = df_pw.groupby(['code'])
KM_values = {}

for code, group in grouped_data:
    KM_values[code] = group['Distance_KM'].mean()

# create a new column with "NA" values for all rows
df_locs['sal'] = np.nan
df_locs['pw_mean_sal'] = np.nan
df_locs['Lat'] = np.nan
df_locs['Lon'] = np.nan
df_locs['KM'] = np.nan


# create a boolean mask to select only the rows where the Station is in sal00_values
mask = df_locs['code'].isin(sal_values.keys())
mask = df_locs['code'].isin(mean_pw_values.keys())
mask = df_locs['code'].isin(Lat_values.keys())
mask = df_locs['code'].isin(Lon_values.keys())
mask = df_locs['code'].isin(KM_values.keys())

# use the mask to select only those rows and add the sal00 values to the new column
df_locs.loc[mask, 'sal'] = [sal_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'pw_mean_sal'] = [mean_pw_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'Lat'] = [Lat_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'Lon'] = [Lon_values[code] for code in df_locs.loc[mask, 'code']]
df_locs.loc[mask, 'KM'] = [KM_values[code] for code in df_locs.loc[mask, 'code']]


df_locs = df_locs.sort_values('Site')

#df_locs
col_order = df_locs["code"].tolist()
col_maxd = [round(x, 1) for x in col_maxd]
col_sal = df_locs["sal"].tolist()
col_sal = [round(x, 1) for x in col_sal]
col_site = df_locs["Site"].tolist()
col_camp = df_locs["Project"].tolist()


sub_num = len(df_locs)-1
width_num = len(df_locs)

df_locs
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_32220\3091680973.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_locs = df_r.groupby('code')['Site','Project'].max().reset_index()
#              code   Site  Project        sal  pw_mean_sal        Lat  \
# 0   St.11_GOM21FA  St.11  GOM21FA  34.918362    36.650000  28.212560
# 1   St.12_GOM21FA  St.12  GOM21FA  34.929702    36.636364  28.594160
# 2   St.13_GOM21FA  St.13  GOM21FA  35.167441    36.958333  28.522860
# 3   St.14_GOM21FA  St.14  GOM21FA  36.358073    37.500000  28.911083
# 4   St.15_GOM21FA  St.15  GOM21FA  35.732539    38.320000  28.950640
# 5   St.16_GOM21FA  St.16  GOM21FA  36.291365    37.916667  28.883543
# 6    St.2_GOM21FA   St.2  GOM21FA  35.167441    36.652174  28.522860
# 7    St.4_GOM21FA   St.4  GOM21FA  31.906647    30.916667  28.795860
# 8    St.7_GOM21FA   St.7  GOM21FA  36.213451    37.761905  28.911083
# 9    St.7_GOM22SP   St.7  GOM22SP  35.533510    37.842105  28.917240
# 10   St.9_GOM21FA   St.9  GOM21FA  36.313978    37.545455  28.781940
# 11   St.9_GOM22SP   St.9  GOM22SP  36.402086    38.318182  28.787320
# 12  St.MK_GOM21FA  St.MK  GOM21FA  31.427814    33.928571  28.913680
#
#           Lon          KM
# 0   28.212560  110.203442
# 1   28.594160   70.178478
# 2   28.522860   78.975797
# 3   28.911083   67.195205
# 4   28.950640   44.491505
# 5   28.883543   42.110633
# 6   28.522860   78.975797
# 7   28.795860  147.815867
# 8   28.911083   67.195205
# 9   28.917240   65.819944
# 10  28.781940   54.278145
# 11  28.787320   54.404978
# 12  28.913680  109.183143

# %%
station_vals = col_order

fig, axs = plt.subplots(nrows=1, ncols=len(station_vals), figsize=(len(station_vals)*3, 10))

for j, station_val in enumerate(station_vals):
    ax = axs[j]
    
    #get data 
    data = df_r[(df_r['code'] == station_val)]
        
    #get vars 
    sal = data['Salinity'] 
    sal = np.asarray(sal, dtype=float).ravel()
    
    sal_mean = sal.mean()
    sal_sd = sal.std()
    sal_mean_round = round(sal_mean, 1)

    depth = data['Depth'] #X var 
    depth = np.asarray(depth, dtype=float).ravel()
    
    cal = data['fit'] #X var 
    cal = np.asarray(cal, dtype=float).ravel()
    
    #PLOT Sal
    ax.plot(sal, depth, 'o', ls='-', c='black')
    ax.set_xlim(25,50)
    ax.set_ylim(42,-1)
    ax.axhline(y=0, color='grey', linestyle='-', label='Sediment Water Interface')
    
    #plot iron 2 
    ax3 = ax.twiny()
    ax3.plot(cal, depth, 'o', ls='-', c='b')
    #Set x-axis label on bottom subplots
    ax3.xaxis.set_ticks_position('bottom')
    ax3.xaxis.set_label_position('bottom')
    ax3.spines['bottom'].set_position(('outward', 50))
    ax3.set_xlabel('Calcuated PSU', size= 20, c='b')
    
    #plot lables 
    #Set x-axis label on bottom subplots
    ax.set_xlabel('Mesured PSU', size = 20, c='black')
    #Set y-axis label on bottom subplots
    if j == 0:
        ax.set_ylabel('Depth (cm)', size= 20)
    
    #turn off other axis
    if j != 0:
        ax.set_yticklabels([])
        
    ax.set_title(f'{col_site[j]}\n{col_camp[j]}\n Depth: {col_maxd[j]} meters', size = 20)
    ax.text(26, 40, f'Bottom Water: {col_sal[j]} PSU', size = 11)
    ax.text(26, 41, f'Mean Pore Water: {sal_mean_round} PSU', size = 11)

    
# add a global title to the figure
fig.suptitle("", size = 20)
fig.set_facecolor('w')
plt.tight_layout()

#save plot 
#plt.savefig("../../../Data_Thesis/FIGS/Pore_water_profiles/GOM2021.png")

# show the plot
plt.show()

# %%
data['fit']
