# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import interpolate
from scipy.interpolate import pchip_interpolate
import numpy as np
import math
from pandas import Series
from lmfit import Model, Parameter, report_fit
import scipy.ndimage
from scipy.ndimage import gaussian_filter1d
from scipy.signal import savgol_filter
from numpy import ones,vstack
from numpy.linalg import lstsq

# %%
files = glob.glob('../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147/*.txt')
files

#here is where the output will go 
path2 = '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147.csv'
files
# Out:
# ['../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214331_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214332_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214333_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214334_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214334_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214335_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214335_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214336_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214336_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214337_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214338_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214339_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214340_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214340_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214431_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214432_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214432_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214433_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214433_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214434_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214434_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214435_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214437_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214438_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214438_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214439_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214439_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214439_Absorbance_03.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214440_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214440_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214531_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214532_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214532_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214533_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214533_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214534_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214535_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214535_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214536_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214536_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214537_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214537_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214538_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214538_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214539_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214539_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214540_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214540_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214631_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214631_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214632_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214633_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214633_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214634_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214634_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214635_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214636_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214636_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214637_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214638_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214639_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214640_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214731_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214731_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214732_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214733_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214733_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214734_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214735_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214736_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214737_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214737_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214738_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214739_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214739_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214740_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\214740_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B1_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B1_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B2_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B3_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B3_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B4_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B4_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\B5_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS1_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS2_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS2_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS3_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS4_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS5_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\CS5_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214335_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214335_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214432_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214531_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214531_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214636_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214636_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\LD214731_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214336_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214434_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214532_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214532_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214637_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214637_Absorbance_02.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214732_Absorbance_01.txt',
#  '../../../Data_Thesis/Iron/WC_FeT_Rerun/GOM21FA_2143_2144_2145_2146_2147\\MS214732_Absorbance_02.txt']

# %%
def GET_DATA(name):
    df = pd.read_csv(name, skiprows=15, sep='\t', names=['wl', 'abs'], )
    df['abs'] = df['abs']
    #df['wl'] = df['wl']
    #bcorr = df[(df['wl']>=700) & (df['wl']<=701)]['abs'].mean() # a float corection with just 700 nm 
    bcorr = df[(df['wl']>=700) & (df['wl']<=750)]['abs'].mean() # a float corection with 700 to 750 nm 
    df['abs'] = df['abs'] - bcorr
    x = df['wl']
    y = df['abs'] 
    pchip_obj1 = scipy.interpolate.PchipInterpolator(x, y, axis=0, extrapolate=None)
    xi = np.arange(189,881,1)
    yi = pchip_obj1(xi)
    d = {'wl': xi, 'abs': yi}
    df = pd.DataFrame(d)
    return df

# %%
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function 
    ID = f.split("\\")[1] #takes junk out of the file name to make a single ID 
    df = df.rename(columns={'abs': ID}) # renames the abs col to the new id 
    df = df.set_index('wl', drop=True) # makes the wl the new index, aka the rows 
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=1, ignore_index=False) # adds all the things in the frame together to make a new df 
df['wl'] = df.index
df
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_10644\4289825241.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['wl'] = df.index
#      214331_Absorbance_01.txt  214332_Absorbance_01.txt  \
# wl
# 189                 -1.867736                  0.004415
# 190                  0.082504                  0.004415
# 191                 -0.372338                 -0.436363
# 192                  0.114244                  0.508055
# 193                 -0.242423                 -0.715618
# ..                        ...                       ...
# 876                 -0.000457                 -0.055099
# 877                 -0.014694                 -0.005691
# 878                  0.000413                  0.016512
# 879                  0.008477                  0.004692
# 880                  0.045915                  0.015825
#
#      214333_Absorbance_01.txt  214334_Absorbance_01.txt  \
# wl
# 189                 -2.270804                 -1.519629
# 190                  0.079087                 -0.051561
# 191                 -0.103804                 -0.422808
# 192                  0.133801                  0.194759
# 193                 -0.042829                 -0.603759
# ..                        ...                       ...
# 876                 -0.032123                 -0.052722
# 877                 -0.000456                 -0.006796
# 878                 -0.015053                 -0.013028
# 879                 -0.025993                  0.003279
# 880                  0.010298                  0.001754
#
#      214334_Absorbance_02.txt  214335_Absorbance_01.txt  \
# wl
# 189                 -0.058051                -15.460295
# 190                 -0.058051                 -0.108401
# 191                 -0.334587                 -0.327156
# 192                  0.286504                  0.529567
# 193                 -0.488562                 -0.641316
# ..                        ...                       ...
# 876                 -0.033754                 -0.058459
# 877                 -0.011363                  0.003405
# 878                 -0.006994                 -0.047812
# 879                 -0.010850                  0.010655
# 880                  0.027618                  0.036664
#
#      214335_Absorbance_02.txt  214336_Absorbance_01.txt  \
# wl
# 189                 -0.070276                  1.645704
# 190                  0.078969                  0.091713
# 191                 -0.296143                 -0.168040
# 192                  0.155586                  0.142196
# 193                 -0.443503                 -0.717117
# ..                        ...                       ...
# 876                 -0.047618                 -0.026366
# 877                 -0.005673                 -0.007850
# 878                  0.005454                 -0.009610
# 879                  0.013239                 -0.013691
# 880                 -0.010974                  0.012005
#
#      214336_Absorbance_02.txt  214337_Absorbance_01.txt  ...  \
# wl                                                       ...
# 189                  0.386892                -20.751933  ...
# 190                  0.071490                 -0.241575  ...
# 191                 -0.462851                 -0.397882  ...
# 192                  0.348637                  0.237173  ...
# 193                 -0.840917                 -0.522011  ...
# ..                        ...                       ...  ...
# 876                 -0.029194                 -0.021926  ...
# 877                 -0.020783                 -0.002574  ...
# 878                 -0.042414                  0.006786  ...
# 879                 -0.008962                  0.014121  ...
# 880                  0.010529                  0.014701  ...
#
#      LD214731_Absorbance_01.txt  MS214336_Absorbance_01.txt  \
# wl
# 189                   -0.246369                  -11.807604
# 190                    0.116882                   -0.154239
# 191                   -0.419229                   -0.134854
# 192                    0.377749                    0.330876
# 193                   -0.517365                   -0.541124
# ..                          ...                         ...
# 876                   -0.061087                   -0.037859
# 877                   -0.032703                   -0.019973
# 878                   -0.002142                   -0.063849
# 879                   -0.024800                   -0.015148
# 880                   -0.001241                    0.049773
#
#      MS214434_Absorbance_01.txt  MS214532_Absorbance_01.txt  \
# wl
# 189                   -0.728824                   -1.007050
# 190                    0.122241                    0.119564
# 191                   -0.149357                   -0.291832
# 192                    0.064921                    0.322742
# 193                   -0.742729                   -0.591506
# ..                          ...                         ...
# 876                   -0.045977                   -0.069004
# 877                   -0.011967                   -0.028485
# 878                   -0.029376                   -0.069493
# 879                   -0.004114                   -0.018131
# 880                    0.022995                   -0.023291
#
#      MS214532_Absorbance_02.txt  MS214637_Absorbance_01.txt  \
# wl
# 189                  -14.984781                  -24.823499
# 190                   -0.119344                   -0.273244
# 191                   -0.335521                   -0.386321
# 192                    0.558364                    0.419402
# 193                   -0.103563                   -0.449619
# ..                          ...                         ...
# 876                   -0.046991                   -0.028820
# 877                   -0.005955                   -0.019135
# 878                   -0.021377                   -0.061254
# 879                   -0.017776                    0.002170
# 880                    0.020304                    0.002207
#
#      MS214637_Absorbance_02.txt  MS214732_Absorbance_01.txt  \
# wl
# 189                   -7.679883                    0.838834
# 190                   -0.344849                    0.126756
# 191                   -0.273123                   -0.201301
# 192                    0.389933                    0.609532
# 193                    0.015177                   -0.438450
# ..                          ...                         ...
# 876                   -0.082709                   -0.035760
# 877                   -0.029532                   -0.019033
# 878                   -0.020944                   -0.029480
# 879                   -0.011521                    0.009679
# 880                    0.010312                   -0.011486
#
#      MS214732_Absorbance_02.txt   wl
# wl
# 189                    5.209170  189
# 190                    0.145328  190
# 191                   -0.030319  191
# 192                    0.933592  192
# 193                    0.313386  193
# ..                          ...  ...
# 876                   -0.050841  876
# 877                   -0.021959  877
# 878                   -0.035065  878
# 879                   -0.014672  879
# 880                    0.030191  880
#
# [692 rows x 109 columns]

# %%
#HERE WE ARE GOING TO AVERAGE THE SCANNS TO GET A VALUE FOR EACH WAVELENTH
#this filters eveything by all that have the work 'Absorbance' with anything after it 
#and turns it into a new object 
d = df.filter(regex='Absorbance*', axis=1)
#this splits the column names by 
#edit here to make the names a 6 diget number code 
names = d.columns.str.rsplit('_', n=7).str[0]
#this part groups evethign by the sample ID that we have in names then avarages all scanns regardless of how many there are 
df = d.groupby(names, axis=1).mean()
df['wl'] = df.index
df
# Out:
#        214331    214332    214333    214334    214335    214336     214337  \
# wl
# 189 -1.867736  0.004415 -2.270804 -0.788840 -7.765285  1.016298 -20.751933
# 190  0.082504  0.004415  0.079087 -0.054806 -0.014716  0.081601  -0.241575
# 191 -0.372338 -0.436363 -0.103804 -0.378697 -0.311649 -0.315446  -0.397882
# 192  0.114244  0.508055  0.133801  0.240631  0.342577  0.245416   0.237173
# 193 -0.242423 -0.715618 -0.042829 -0.546160 -0.542410 -0.779017  -0.522011
# ..        ...       ...       ...       ...       ...       ...        ...
# 876 -0.000457 -0.055099 -0.032123 -0.043238 -0.053038 -0.027780  -0.021926
# 877 -0.014694 -0.005691 -0.000456 -0.009080 -0.001134 -0.014317  -0.002574
# 878  0.000413  0.016512 -0.015053 -0.010011 -0.021179 -0.026012   0.006786
# 879  0.008477  0.004692 -0.025993 -0.003786  0.011947 -0.011326   0.014121
# 880  0.045915  0.015825  0.010298  0.014686  0.012845  0.011267   0.014701
#
#        214338    214339    214340  ...  LD214432  LD214531  LD214636  \
# wl                                 ...
# 189  1.112994  0.609972 -1.627012  ...  0.193325  5.037690  2.422892
# 190  0.044983  0.048117 -0.031493  ...  0.099030  0.046492  0.086583
# 191 -0.168518 -0.290189 -0.399701  ... -0.420028  0.056534 -0.189570
# 192 -0.014691  0.909802  0.351590  ...  0.477879  0.464018  0.348602
# 193 -0.397882 -0.695868 -0.446438  ... -0.347125 -0.373261 -0.303197
# ..        ...       ...       ...  ...       ...       ...       ...
# 876 -0.043245  0.047276 -0.051102  ... -0.058857 -0.060821 -0.059336
# 877  0.001542  0.023909 -0.016084  ... -0.012659 -0.049191 -0.037856
# 878 -0.041299  0.045417 -0.025470  ... -0.044509 -0.027875 -0.045973
# 879  0.005485  0.047453 -0.019197  ... -0.009992 -0.019919 -0.021996
# 880 -0.024631  0.080841  0.004479  ... -0.004254 -0.002446 -0.025561
#
#      LD214731   MS214336  MS214434  MS214532   MS214637  MS214732   wl
# wl
# 189 -0.246369 -11.807604 -0.728824 -7.995916 -16.251691  3.024002  189
# 190  0.116882  -0.154239  0.122241  0.000110  -0.309047  0.136042  190
# 191 -0.419229  -0.134854 -0.149357 -0.313676  -0.329722 -0.115810  191
# 192  0.377749   0.330876  0.064921  0.440553   0.404668  0.771562  192
# 193 -0.517365  -0.541124 -0.742729 -0.347535  -0.217221 -0.062532  193
# ..        ...        ...       ...       ...        ...       ...  ...
# 876 -0.061087  -0.037859 -0.045977 -0.057998  -0.055764 -0.043300  876
# 877 -0.032703  -0.019973 -0.011967 -0.017220  -0.024333 -0.020496  877
# 878 -0.002142  -0.063849 -0.029376 -0.045435  -0.041099 -0.032273  878
# 879 -0.024800  -0.015148 -0.004114 -0.017953  -0.004676 -0.002497  879
# 880 -0.001241   0.049773  0.022995 -0.001493   0.006260  0.009352  880
#
# [692 rows x 70 columns]

# %%
#HERE, WE MAKE A QUICK AND DIRTY GRAPH OF THE DATA TO SAVE AND CHECK WORK 
fig, ax = plt.subplots(figsize=(10,8))
df.plot(label='', ax=ax)
ax.set_ylim(-.1,3)
ax.set_xlim(250,800)
ax.set_xlabel("Wavelength")
ax.set_ylabel("a$_{CDOM}$ (1/m)")
ax.set_title("BC_ABS_BLU22_2226_GB")
# Out:
# Text(0.5, 1.0, 'BC_ABS_BLU22_2226_GB')

# %%
Frames = []
maxfev = 10000000
for (columnName, columnData) in df.iteritems():
    col = columnName
    
    abs_562 = df[(df['wl']==562)][col].mean()
    
    ydata = df[(df['wl']>=450) & (df['wl']<=700)][col]
    xdata = df[(df['wl']>=450) & (df['wl']<=700)]['wl']
    ydata = np.asarray(ydata, dtype=float).ravel()
    xdata = np.asarray(xdata, dtype=float).ravel()
    
    inter = scipy.integrate.simps(ydata, x=xdata, even='avg')
    
    dict = {'sample':[columnName],
        'abs_562':[abs_562], 
        'intagration':[inter],}
    ss_outs = pd.DataFrame(dict)
    ss_outs = ss_outs.set_index('sample', drop=True)
    Frames.append(ss_outs)

ss_outs = pd.concat(Frames, axis=0, ignore_index=False) # adds all the things in the frame together to make a new df 
ss_outs = ss_outs.drop('wl')
ss_outs.to_csv(path2)

#ss_outs['conc'] = ss_outs.index.astype(int)
ss_outs
# Out:
#            abs_562  intagration
# sample
# 214331    0.071389    10.645629
# 214332    0.042364     7.543610
# 214333    0.034855     7.001211
# 214334    0.062297    10.186546
# 214335    0.045572     8.314579
# ...            ...          ...
# MS214336  0.096668    13.102177
# MS214434  0.087594    12.427797
# MS214532  0.098682    14.406497
# MS214637  0.078852    11.723294
# MS214732  0.093486    13.493375
#
# [69 rows x 2 columns]

# %%
# create scatter plot
fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(ss_outs['conc'], ss_outs['abs_562'], facecolor='none', edgecolor='black')

# add linear regression line
x = ss_outs['conc']
y = ss_outs['abs_562']
coefficients = np.polyfit(x, y, 1)
slope = coefficients[0]
line = np.poly1d(coefficients)
ax.plot(x, line(x), color='red', linestyle='--')

# calculate R-squared
residuals = y - line(x)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y - np.mean(y))**2)
r_squared = 1 - (ss_res / ss_tot)

# set x and y labels and title
ax.set_xlabel('Conc FeT nm')
ax.set_ylabel('Abs 562')
ax.set_title('STD CURVE basline corrected')

# print equation of line and R-squared on graph
equation = f"y = {slope:.3f}x + {coefficients[1]:.3f}"
r2_text = f"R-squared: {r_squared:.3f}"
ax.text(0.15, 0.90, equation, transform=ax.transAxes, fontsize=12, color='red')
ax.text(0.15, 0.85, r2_text, transform=ax.transAxes, fontsize=12, color='red')

# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <module>
#       1 # create scatter plot
#       2 fig, ax = plt.subplots(figsize=(10, 8))
# ----> 3 ax.scatter(ss_outs['conc'], ss_outs['abs_562'], facecolor='none', edgecolor='black')
#       5 # add linear regression line
#       6 x = ss_outs['conc']
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\miniconda3\envs\Bugs\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'conc'

# %%
# create scatter plot
fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(ss_outs['conc'], ss_outs['intagration'], facecolor='none', edgecolor='black')

# add linear regression line
x = ss_outs['conc']
y = ss_outs['intagration']
coefficients = np.polyfit(x, y, 1)
slope = coefficients[0]
line = np.poly1d(coefficients)
ax.plot(x, line(x), color='red', linestyle='--')

# calculate R-squared
residuals = y - line(x)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y - np.mean(y))**2)
r_squared = 1 - (ss_res / ss_tot)

# set x and y labels and title
ax.set_xlabel('Conc FeT nm')
ax.set_ylabel('area intagration')
ax.set_title('STD CURVE basline corrected')

# print equation of line and R-squared on graph
equation = f"y = {slope:.3f}x + {coefficients[1]:.3f}"
r2_text = f"R-squared: {r_squared:.3f}"
ax.text(0.15, 0.90, equation, transform=ax.transAxes, fontsize=12, color='red')
ax.text(0.15, 0.85, r2_text, transform=ax.transAxes, fontsize=12, color='red')

# show plot
plt.show()

# %% [markdown]
# EXPERIMENTAL
