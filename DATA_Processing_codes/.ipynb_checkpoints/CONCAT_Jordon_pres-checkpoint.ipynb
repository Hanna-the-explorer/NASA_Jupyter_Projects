# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns

# %%
files = glob.glob('../../../Data_Thesis/CDOM/SPECTRA/*GOM*.csv')
#files = glob.glob('../../../Data_Thesis/CDOM/OUTPUTS/*GOM*.csv')
files
path_save = '../../../Data_Thesis/CDOM/CDOM_GOM_SPECTRA.csv'
#path_save = '../../../Data_Thesis/CDOM/CDOM_GOM_SPECTRA.csv'
files
# Out:
# ['../../../Data_Thesis/CDOM/SPECTRA\\ABS_BC_GOM21FA_1_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_BC_GOM21FA_2_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_BC_GOM22SP_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_BC_GOM22SU_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_BC_MK_GOM21FA_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_PW_GOM21FA_1_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_PW_GOM21FA_2_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_PW_GOM22SP_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_PW_GOM22SU_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_RHZ_GOM22SP_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_RZ_GOM21FA_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_RZ_GOM22SU_2242_10CM_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_RZ_GOM22SU_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM21FA_1_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM21FA_2_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.13_2221_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.14_2215_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.15_2218_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.16_2216_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.2_222081_1cm_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.2_222081_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.2_2220_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.4_2223_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.5B_2217_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.7_2214_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.9_2219_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SP_St.MK_2222_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\ABS_WC_GOM22SU_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2119_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2120_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2121_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2122_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2123_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2124_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2125_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2126_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2127_1_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2127_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2128_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\BC_ABS_GOM21SU_ID2129_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2121_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2122_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2123_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2125_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2126_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2127_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2128_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\PW_ABS_GOM21SU_ID2129_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2119_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2120_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2121_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2123_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2124_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2125_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2126_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2127_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2128_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2129_Pchip_wavelenths.csv',
#  '../../../Data_Thesis/CDOM/SPECTRA\\WC_ABS_GOM21SU_ID2130_Pchip_wavelenths.csv']

# %%
def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

# %%
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)
df
# Out:
#                189       190       191       192       193       194  \
# 214841    0.008700  0.008700 -0.273188 -0.140453 -0.836404 -0.229151
# 214842   -0.099671 -0.099671 -0.550780 -0.095769 -1.420158 -0.293696
# 214843   -0.332555 -0.332555 -0.495243 -0.342500 -2.181806 -0.611948
# 214844   -0.192604 -0.192604 -0.536219 -0.342446 -1.676064 -0.338320
# 214845    0.062842  0.062842 -0.202525 -0.076219 -1.284972 -0.098134
# ...            ...       ...       ...       ...       ...       ...
# ID213036  0.638017  0.638017  0.681774  0.726113  0.774544  0.752025
# ID213037  0.029995  0.029995  0.229204  0.266603  0.422067  0.370424
# ID213038  0.001327  0.001327 -0.073544  0.238383 -0.238149  0.235855
# ID213039 -0.629455 -0.629455 -0.350792 -0.240589 -0.514001 -0.230584
# ID213040 -0.403669 -0.403669 -0.615545 -0.257725 -0.499816 -0.482507
#
#                195       196       197       198  ...       872       873  \
# 214841    0.109767  0.111535  0.012094  1.370150  ...  0.013246 -0.674058
# 214842   -0.022831 -0.209381 -0.621339  0.177986  ...  0.476482 -0.931199
# 214843   -0.244359 -0.464302 -0.470569  1.067919  ... -0.611818 -0.913209
# 214844   -0.196835 -0.341007  0.208293 -0.354670  ... -0.182642 -0.836349
# 214845    0.134677 -0.155197  0.157104  1.039162  ...  0.189448 -0.368026
# ...            ...       ...       ...       ...  ...       ...       ...
# ID213036  0.625061  1.099610  0.628941  0.059937  ... -1.206985 -2.882707
# ID213037  0.175164  0.745496  0.307284 -0.954708  ... -0.805031 -1.065157
# ID213038 -0.026432  0.351947 -0.064888 -1.275790  ...  0.502111 -0.371830
# ID213039 -0.371766  0.094573 -0.129847 -1.828797  ...  1.429183  0.903707
# ID213040 -0.929797 -0.053562 -0.314819 -1.726652  ...  1.102262  0.272780
#
# 214843   -0.437620 -0.695287 -2.280442   0.016046  -1.978964  -1.855696
# 214844   -1.217384 -0.184605 -2.091716  -0.229034  -1.799124  -1.816086
# 214845   -0.525386 -0.279613 -1.392138   0.039518  -1.135811  -1.490285
# ...            ...       ...       ...        ...        ...        ...
# ID213036 -2.129962 -2.221550 -5.444529  -2.369092  -6.810982   8.143894
# ID213037  0.203355 -0.044205 -3.928939   0.567737   4.305150  -0.977441
# ID213038 -0.105849  1.228842 -2.076316  -0.016904   3.491264  -4.464910
# ID213039  0.473870  2.751837 -0.212833  11.401836  22.053114 -11.254214
# ID213040  1.527954  4.586466  2.051755   1.535898   0.897526 -11.993858
#
#                 880     bcorr
# 214841    -0.116904  0.152235
# 214842    -0.378195  0.195728
# 214843    -1.143906  0.271299
# 214844    -1.128555  0.158905
# 214845    -0.268872 -0.151655
# ...             ...       ...
# ID213036   1.160798 -1.160798
# ID213037  15.193738 -0.960407
# ID213038   0.807848 -0.959375
# ID213039  -2.478850 -0.902040
# ID213040  -3.993568 -0.897526
#
# [2243 rows x 693 columns]

# %%
#make a col to play with 
df['sample_ID'] = df.index
df['sample_ID'] = df['sample_ID'].astype(str)

#clean up odd stuff left over from proccessing 
df_six = df.loc[df['sample_ID'].str.len()==6]
df_six.index = df_six['sample_ID'] 

df_eight = df.loc[df['sample_ID'].str.len()==8]
df_eight['sample_ID'] = df_eight['sample_ID'].str[2:]
df_eight.index = df_eight['sample_ID'] 

#adds them together 
frames = [df_eight, df_six]
df = pd.concat(frames)

#take it out if it is not a number then delet the row and rename the index 
df = df[pd.to_numeric(df['sample_ID'], errors='coerce').notnull()]
df = df.rename(columns={"sample_ID": "sample"})
df.index = df['sample'] 
df = df.drop(['sample'], axis=1)

df
# Out:
# C:\Users\12532\AppData\Local\Temp\ipykernel_23500\2363079800.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eight['sample_ID'] = df_eight['sample_ID'].str[2:]
#               189        190        191       192       193       194  \
# sample
# 211937  10.639455  10.639455 -10.259155 -5.386337  0.490235  3.007472
# 211938   4.867738   4.867738  -1.905737 -3.123809  3.732659  8.351921
# 211939   2.227653   2.227653  -2.887888 -5.872011 -1.813638  2.772679
# 211940   1.280435   1.280435  -4.424094 -4.437968  1.733900 -3.560655
# 211941   5.093712   5.093712  -3.939108 -3.235738 -1.605098 -3.888600
# ...           ...        ...        ...       ...       ...       ...
# 212006   0.131409   0.162024   0.216830  0.196444  0.094711  0.140487
# 212007   0.105969   0.131493   0.125061  0.279744  0.110293  0.162156
# 212008   0.153556   0.065255   0.215976  0.212472  0.075799  0.185381
# 212009   0.190405   0.159044   0.217676  0.257958  0.288392  0.173317
# 212010   0.229346   0.127512   0.182598  0.225488  0.204114  0.206619
#
#              195        196       197       198  ...       872       873  \
# sample                                           ...
# 211937 -3.023859 -25.451419 -3.831760  1.710464  ... -0.357617 -0.044592
# 211938 -2.380785 -23.775372  5.997602  1.988566  ... -0.287217 -0.095003
# 211939  5.125789 -23.633515  3.435051  1.368504  ... -0.383056 -0.296016
# 211940  9.350108 -24.871943 -1.511629  1.467232  ... -0.475381 -0.095266
# 211941 -4.689640 -23.785237  4.467218  0.921723  ... -0.339728 -0.319011
# ...          ...        ...       ...       ...  ...       ...       ...
# 212006  0.179670   0.096075  0.252367  0.384976  ...  0.000000  0.000000
# 212007  0.233262   0.146567  0.288199  0.358029  ...  0.000000  0.000000
# 212008  0.210958   0.195542  0.268708  0.356797  ...  0.000000  0.000000
# 212009  0.302058   0.182291  0.338234  0.431045  ...  0.000000  0.000000
# 212010  0.338706   0.160026  0.297947  0.361762  ...  0.000000  0.000000
#
#              874       875       876       877       878       879       880  \
# sample
# 211937 -0.110694 -0.181238 -0.027434 -0.312916 -0.366800 -0.161055 -0.625023
# 211938 -0.387544 -0.283539 -0.236600 -0.171661 -0.456474 -0.239825 -0.597193
# 211939 -0.324214 -0.311437 -0.198432 -0.287402 -0.435456 -0.236456 -0.622502
# 211940 -0.313006 -0.351204 -0.328085 -0.431814 -0.514500 -0.429834 -0.662402
# 211941 -0.340857 -0.472318 -0.226472 -0.316494 -0.662063 -0.309034 -0.902425
# ...          ...       ...       ...       ...       ...       ...       ...
# 212006  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 212007  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 212008  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 212009  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 212010  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            bcorr
# sample
# 211937 -0.851705
# 211938 -0.953789
# 211939 -0.739915
# 211940 -0.782987
# 211941 -0.849283
# ...          ...
# 212006 -0.003297
# 212007  0.005181
# 212008 -0.005652
# 212009 -0.005181
# 212010 -0.045212
#
# [2118 rows x 693 columns]

# %%
#save it for later 
df.to_csv(path_save)

# %%
meta = pd.read_csv("../../../Data_Thesis/meta_data.csv")
meta['Sample'] = meta['Sample'].astype(str)
meta['Sample'] = meta['Sample'].str[:6]
meta.index = meta['Sample'] 
meta = meta.loc[meta['Sample'].str.len()==6]
meta = meta.loc[meta['BC_time']>0]
meta
# Out:
#         Sample       Date     Trip Station  Lat  Lon  Water_dapth  \
# Sample
# 211937  211937  7/16/2021  GOM2021   St.MK  NaN  NaN          NaN
# 211938  211938  7/16/2021  GOM2021   St.MK  NaN  NaN          NaN
# 211939  211939  7/16/2021  GOM2021   St.MK  NaN  NaN          NaN
# 211940  211940  7/16/2021  GOM2021   St.MK  NaN  NaN          NaN
# 211941  211941  7/16/2021  GOM2021   St.MK  NaN  NaN          NaN
# ...        ...        ...      ...     ...  ...  ...          ...
# 225354  225354  7/24/2022  GOM22SU   St.MK  NaN  NaN          NaN
# 225355  225355  7/24/2022  GOM22SU   St.MK  NaN  NaN          NaN
# 225356  225356  7/24/2022  GOM22SU   St.MK  NaN  NaN          NaN
# 225357  225357  7/24/2022  GOM22SU   St.MK  NaN  NaN          NaN
# 225358  225358  7/24/2022  GOM22SU   St.MK  NaN  NaN          NaN
#
#        Sample_depth Sample_depth_units  Wavguide_Path_lengths    BC_time  \
# Sample
# 211937          NA                   M                    NaN   0.200000
# 211938          NA                   M                    NaN   1.200000
# 211939          NA                   M                    NaN   2.200000
# 211940          NA                   M                    NaN   3.200000
# 211941          NA                   M                    NaN   4.200000
# ...             ...                ...                    ...        ...
# 225354          NA                   M                  0.489  10.166667
# 225355          NA                   M                  0.489  10.933333
# 225356          NA                   M                  0.489  11.700000
# 225357          NA                   M                  0.489  12.466667
# 225358          NA                   M                  0.489  13.233333
#
#         BC_Chamber_vol_(L)     Type Waveguide_used Notes Flagged  \
# Sample
# 211937            0.056902  LANDSYR            NaN   BC1     NaN
# 211938            0.056902  LANDSYR            NaN   BC2     NaN
# 211939            0.056902  LANDSYR            NaN   BC3     NaN
# 211940            0.056902  LANDSYR            NaN   BC4     NaN
# 211941            0.056902  LANDSYR            NaN   BC5     NaN
# ...                    ...      ...            ...   ...     ...
# 225354            0.053721  LANDSYR  LWCC 50 CM #2  BC14     NaN
# 225355            0.053721  LANDSYR  LWCC 50 CM #2  BC15     NaN
# 225356            0.053721  LANDSYR  LWCC 50 CM #2  BC16     NaN
# 225357            0.053721  LANDSYR  LWCC 50 CM #2  BC17     NaN
# 225358            0.053721  LANDSYR  LWCC 50 CM #2  BC18     NaN
#
#         Core_Salinity Core_Temp_deg_C
# Sample
# 211937            NaN             NaN
# 211938            NaN             NaN
# 211939            NaN             NaN
# 211940            NaN             NaN
# 211941            NaN             NaN
# ...               ...             ...
# 225354            NaN             NaN
# 225355            NaN             NaN
# 225356            NaN             NaN
# 225357            NaN             NaN
# 225358            NaN             NaN
#
# [704 rows x 18 columns]

# %%
TOC = pd.read_csv("../../../Data_Thesis/TOC/TOC_GOM.csv")
TOC['Sample ID'] = TOC['Sample ID'].astype(str)
TOC['Sample ID'] = TOC['Sample ID'].str[:6]
TOC.index = TOC['Sample ID'] 

TOC
# Out:
#           Sample ID Treatment Campaign        Date Location  Depth  Time  \
# Sample ID
# 215542       215542       P2F  GOM21FA  2021-11-13    St.16    NaN   1.2
# 215543       215543       P2F  GOM21FA  2021-11-13    St.16    NaN   2.2
# 215544       215544       P2F  GOM21FA  2021-11-13    St.16    NaN   3.2
# 215545       215545       P2F  GOM21FA  2021-11-13    St.16    NaN   4.2
# 215546       215546       P2F  GOM21FA  2021-11-13    St.16    NaN   5.2
# ...             ...       ...      ...         ...      ...    ...   ...
# 224935       224935       P2F  GOM22SU  2022-07-19     St.2  53.98   NaN
# 224936       224936       P2F  GOM22SU  2022-07-19     St.2  24.40   NaN
# 224937       224937       P2F  GOM22SU  2022-07-19     St.2   6.20   NaN
# 224938       224938       P2F  GOM22SU  2022-07-19     St.2   2.80   NaN
# 224940       224940       P2F  GOM22SU  2022-07-19     St.2   1.70   NaN
#
#            NPOC Conc (mg/L)       TN Conc (mg/L)  NPOC Conc (uM)  \
# Sample ID
# 215542              0.00000   -9.328573915033273        0.000000
# 215543              0.00000  -14.102340606241707        0.000000
# 215544              0.00000  -16.145587049949597        0.000000
# 215545              0.00000   -18.13471681295637        0.000000
# 215546              0.00000   15.419474677392298        0.000000
# ...                     ...                  ...             ...
# 224935              2.19123                  NaN      182.602484
# 224936                  NaN                  NaN             NaN
# 224937                  NaN                  NaN             NaN
# 224938                  NaN                  NaN             NaN
# 224940                  NaN                  NaN             NaN
#
#            TN Conc (uM)                                              Notes
# Sample ID
# 215542      -666.326708  Basically, All are bad Re-did the cal curve fo...
# 215543     -1007.310043  Basically, All are bad Re-did the cal curve fo...
# 215544     -1153.256218  Basically, All are bad Re-did the cal curve fo...
# 215545     -1295.336915  Basically, All are bad Re-did the cal curve fo...
# 215546      1101.391048  Basically, All are bad Re-did the cal curve fo...
# ...                 ...                                                ...
# 224935              NaN                                All NA for bad data
# 224936              NaN                                All NA for bad data
# 224937              NaN                                All NA for bad data
# 224938              NaN                                All NA for bad data
# 224940              NaN                                All NA for bad data
#
# [937 rows x 12 columns]

# %%
df['key'] = df.index 
meta['key'] = meta.index

# %%
frames = [meta, df]
result = pd.merge(meta, df, on="key")
result 
result.to_csv('../../../Jordon_pres/Meta_CDOM_data.csv')
