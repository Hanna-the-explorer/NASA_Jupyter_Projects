# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns

# %%
files = glob.glob('../../../IRL22SU/IRL_DATA.csv')
files
# Out:
# ['../../../IRL22SU/IRL_DATA.csv']

# %%
def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

# %%
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)

# %%
num = df._get_numeric_data()
#num[num < 0] = np.nan

# %%
##GET RHZ CORES 
ds_grouped = df.groupby(["Type"])
ds_rz = ds_grouped.get_group("RZ")
#ds_rz = ds_grouped.get_group("PW")
ds_locs = ds_rz.groupby(["Location"])
ds_locs.groups.keys()
# Out:
# dict_keys(['B_point', 'SP', 'S_beach '])

# %%
##PLOT RHZ CORES 

#ds = ds_rz

##Secret beach 
ds = ds_locs.get_group("S_beach ")
titel = "Secret Beach"

sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(4,10))

X = ds["NPOC_uM"] #X var 
X = np.asarray(X, dtype=float).ravel()
Y = ds['Depth'] #Y var
Y = np.asarray(Y, dtype=float).ravel()
X1 = ds['Fe2_uM'] #X var 
X1 = np.asarray(X1, dtype=float).ravel()
X2 = ds['acdom412'] #X var 
X2 = np.asarray(X2, dtype=float).ravel()
X3 = ds['Fe3_uM'] #X var 
X3 = np.asarray(X3, dtype=float).ravel()

Z = None #color

ax.plot(X, Y, 'o', ls='-', c='black')
ax.set_ylim(5.25,-.5)
ax.set_xlim(0,1800)
ax.set_xlabel("DOC uM", size = 15, c='black')
ax.set_ylabel("Depth (cm)", size = 15)
ax.set_title(titel, size = 18)
ax.axhline(y=0, color='black', linestyle='-', label='Sediment Water Interface')
ax.text(125, -.05, 'Sediment Water Interface', fontsize=10)

ax2 = ax.twiny()
ax2.plot(X1, Y,'o', ls='-', c='b')
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 50))
ax2.set_xlabel('Fe (II) uM', size= 15, c='b')
min_val1 = 0
max_val1 = 15
ax2.set_xlim(min_val1,max_val1)

ax3 = ax2.twiny()
ax3.plot(X2, Y,'o', ls='-', c='g')
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
ax3.xaxis.set_ticks_position('bottom')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 150))
ax3.set_xlabel('aCDOM 412 nm', size= 15, c='g')
min_val2 = 0
max_val2 = 15
ax3.set_xlim(min_val2,max_val2)

ax4 = ax3.twiny()
ax4.plot(X3, Y,'o', ls='-', c='r')
ax4.set_frame_on(True)
ax4.patch.set_visible(False)
ax4.xaxis.set_ticks_position('bottom')
ax4.xaxis.set_label_position('bottom')
ax4.spines['bottom'].set_position(('outward', 100))
ax4.set_xlabel('Fe (III) uM', size= 15, c='r')
min_val3 = 0
max_val3 = 15
ax4.set_xlim(min_val3,max_val3)

plt.tight_layout()

plt.savefig('../../../IRL22SU/Plots/Secret_Beach.png')

# %%
##PLOT RHZ CORES 

##Bear point
ds = ds_locs.get_group("B_point")
titel = "Bear Point"

sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(4,10))

X = ds["NPOC_uM"] #X var 
X = np.asarray(X, dtype=float).ravel()
Y = ds['Depth'] #Y var
Y = np.asarray(Y, dtype=float).ravel()
X1 = ds['Fe2_uM'] #X var 
X1 = np.asarray(X1, dtype=float).ravel()
X2 = ds['acdom412'] #X var 
X2 = np.asarray(X2, dtype=float).ravel()
X3 = ds['Fe3_uM'] #X var 
X3 = np.asarray(X3, dtype=float).ravel()

Z = None #color

ax.plot(X, Y, 'o', ls='-', c='black')
ax.set_ylim(5.25,-.5)
ax.set_xlim(0,1800)
ax.set_xlabel("DOC uM", size = 15, c='black')
ax.set_ylabel("Depth (cm)", size = 15)
ax.set_title(titel, size = 18)
ax.axhline(y=0, color='black', linestyle='-', label='Sediment Water Interface')
ax.text(125, -.05, 'Sediment Water Interface', fontsize=10)

ax2 = ax.twiny()
ax2.plot(X1, Y,'o', ls='-', c='b')
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 50))
ax2.set_xlabel('Fe (II) uM', size= 15, c='b')
min_val1 = 0
max_val1 = 15
ax2.set_xlim(min_val1,max_val1)

ax3 = ax2.twiny()
ax3.plot(X2, Y,'o', ls='-', c='g')
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
ax3.xaxis.set_ticks_position('bottom')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 150))
ax3.set_xlabel('aCDOM 412 nm', size= 15, c='g')
min_val2 = 0
max_val2 = 15
ax3.set_xlim(min_val2,max_val2)

ax4 = ax3.twiny()
ax4.plot(X3, Y,'o', ls='-', c='r')
ax4.set_frame_on(True)
ax4.patch.set_visible(False)
ax4.xaxis.set_ticks_position('bottom')
ax4.xaxis.set_label_position('bottom')
ax4.spines['bottom'].set_position(('outward', 100))
ax4.set_xlabel('Fe (III) uM', size= 15, c='r')
min_val3 = 0
max_val3 = 15
ax4.set_xlim(min_val3,max_val3)

plt.tight_layout()

plt.savefig('../../../IRL22SU/Plots/Bear_Point.png')

# %%
##PLOT RHZ CORES 

#ds = ds_rz

##Shorty's pocket RZ
ds = ds_locs.get_group("SP")
titel = "Shorty's Pocket"

##Shorty's pocket PW
#ds = ds_grouped.get_group("PW")
#titel = "Shorty's Pocket"

sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(4,10))

X = ds["NPOC_uM"] #X var 
X = np.asarray(X, dtype=float).ravel()
Y = ds['Depth'] #Y var
Y = np.asarray(Y, dtype=float).ravel()
X1 = ds['Fe2_uM'] #X var 
X1 = np.asarray(X1, dtype=float).ravel()
X2 = ds['acdom412'] #X var 
X2 = np.asarray(X2, dtype=float).ravel()
X3 = ds['Fe3_uM'] #X var 
X3 = np.asarray(X3, dtype=float).ravel()

Z = None #color

ax.plot(X, Y, 'o', ls='-', c='black')
ax.set_ylim(5.25,-.5)
ax.set_xlim(0,1800)
ax.set_xlabel("DOC uM", size = 15, c='black')
ax.set_ylabel("Depth (cm)", size = 15)
ax.set_title(titel, size = 18)
ax.axhline(y=0, color='black', linestyle='-', label='Sediment Water Interface')
ax.text(125, -.05, 'Sediment Water Interface', fontsize=10)

ax2 = ax.twiny()
ax2.plot(X1, Y,'o', ls='-', c='b')
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 50))
ax2.set_xlabel('Fe (II) uM', size= 15, c='b')
min_val1 = 0
max_val1 = 15
ax2.set_xlim(min_val1,max_val1)

ax3 = ax2.twiny()
ax3.plot(X2, Y,'o', ls='-', c='g')
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
ax3.xaxis.set_ticks_position('bottom')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 150))
ax3.set_xlabel('aCDOM 412 nm', size= 15, c='g')
min_val2 = 0
max_val2 = 15
ax3.set_xlim(min_val2,max_val2)

ax4 = ax3.twiny()
ax4.plot(X3, Y,'o', ls='-', c='r')
ax4.set_frame_on(True)
ax4.patch.set_visible(False)
ax4.xaxis.set_ticks_position('bottom')
ax4.xaxis.set_label_position('bottom')
ax4.spines['bottom'].set_position(('outward', 100))
ax4.set_xlabel('Fe (III) uM', size= 15, c='r')
min_val3 = 0
max_val3 = 15
ax4.set_xlim(min_val3,max_val3)

plt.tight_layout()

plt.savefig('../../../IRL22SU/Plots/Shorty_Pocket.png')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from pylab import rcParams

# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="NPOC_uM", y="acdom412", data=df, fit_reg=False, hue='Type_name', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='upper right')
plt.xlim(0,5000)
plt.ylim(0,40)
plt.xlabel('DOC uM', size= 15)
plt.ylabel('aCDOM 412 nm', size= 15)

plt.savefig("../../../IRL22SU/Plots/corvar_doc_cdom.png")

plt.show()

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="FeT_uM", y="acdom412", data=df, fit_reg=False, hue='Type_name', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='upper right')
plt.xlim(0,6)
plt.ylim(0,40)
plt.xlabel('Iron Total uM', size= 15)
plt.ylabel('aCDOM 412 nm', size= 15)

plt.savefig("../../../IRL22SU/Plots/corvar_fet_cdom.png")

plt.show()

# %%
df['fet/doc'] = df['FeT_uM'] / df['NPOC_uM'] 
df['doc/fet'] = df['NPOC_uM'] / df['FeT_uM']

df['log.fet/doc'] = np.log2(df['fet/doc'])

import itertools

mks = itertools.cycle(['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
markers = [next(mks) for i in df["Location"].unique()]

marker = ['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V']
markers = [marker[i] for i in range(len(df["Location"].unique()))]

# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="NPOC_uM", y="acdom412", data=df, fit_reg=False, 
           hue='LAT',
           #markers=markers,
           legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='upper right')
plt.xlim(0,4500)
plt.ylim(0,40)
plt.xlabel('DOC uM', size= 15)
plt.ylabel('aCDOM 412 nm', size= 15)

plt.savefig("../../../IRL22SU/Plots/corvar_doc2_cdom.png")

plt.show()
# Out:
# C:\Users\12532\miniconda3\envs\Bugs\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,8))
ax[0].scatter(df['NPOC_uM'],df['acdom412'], c = df['LAT'])
ax[0].set_xlabel('NPOC_uM', size= 15)
ax[0].set_ylabel('acdom412', size= 15)
ax[0].set_ylim(0,40)
ax[0].set_xlim(0,4500)

ax[1].scatter(df['FeT_uM'],df['acdom412'], c = df['LAT'])
ax[1].set_xlabel('Fe total uM', size= 15)
ax[1].set_ylim(0,40)
ax[1].set_xlim(0,6)
#ax[0,0].set_ylabel('TN Conc (uM)', size= 15)
# Out:
# (0.0, 6.0)

# %%
markers
# Out:
# ['o', 'x', '^', '+', '*', '8', 's', 'p', 'D']

# %%
df["Location"].unique()

markers
# Out:
# ['o', 'x', '^', '+', '*', '8', 's', 'p', 'D']

# %%
df
# Out:
#     Sample_ID Type          Type_name Campaign       Date  Location  \
# 34     227123  PON         ponar grab      IRL  11/3/2022       SLE
# 28     227103   WC       water column      IRL  11/3/2022       SLE
# 35     227125  PON         ponar grab      IRL  11/3/2022        SF
# 30     227105   WC       water column      IRL  11/3/2022        SF
# 29     227104   WC       water column      IRL  11/3/2022        NF
# 33     227122  PON         ponar grab      IRL  11/3/2022        JB
# 27     227102   WC       water column      IRL  11/3/2022        JB
# 14     223500   OW    overlying water  IRL22SU  6/12/2022   B_point
# 15     223501   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 16     223502   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 17     223503   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 18     223504   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 19     223505   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 20     223506   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 21     223507   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 22     223508   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 23     223509   RZ  pore water rhizon  IRL22SU  6/12/2022   B_point
# 24     223511   WC       water column  IRL22SU  6/12/2022   B_point
# 25     223512   WC       water column  IRL22SU  6/12/2022   B_point
# 32     227121  PON         ponar grab      IRL  11/3/2022        TC
# 26     227101   WC       water column      IRL  11/3/2022        TC
# 1      223400   OW    overlying water  IRL22SU  5/28/2022  S_beach
# 2      223401   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 3      223402   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 4      223403   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 5      223404   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 6      223405   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 7      223406   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 8      223407   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 9      223408   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 10     223409   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 11     223410   RZ  pore water rhizon  IRL22SU  5/28/2022  S_beach
# 12     223411   WC       water column  IRL22SU  5/28/2022  S_beach
# 13     223412   WC       water column  IRL22SU  5/28/2022  S_beach
# 36     227126  PON         ponar grab      IRL  11/3/2022        VB
# 31     227106   WC       water column      IRL  11/3/2022        VB
# 50     230301   PW         pore water      IRL  1/11/2023        SP
# 51     230302   PW         pore water      IRL  1/11/2023        SP
# 52     230303   PW         pore water      IRL  1/11/2023        SP
# 53     230304   PW         pore water      IRL  1/11/2023        SP
# 54     230305   PW         pore water      IRL  1/11/2023        SP
# 55     230306   PW         pore water      IRL  1/11/2023        SP
# 56     230307   PW         pore water      IRL  1/11/2023        SP
# 57     230308   PW         pore water      IRL  1/11/2023        SP
# 58     230309   PW         pore water      IRL  1/11/2023        SP
# 59     230310   PW         pore water      IRL  1/11/2023        SP
# 60     230311   PW         pore water      IRL  1/11/2023        SP
# 61     230312   PW         pore water      IRL  1/11/2023        SP
# 62     230313   PW         pore water      IRL  1/11/2023        SP
# 63     230340   WC       water column      IRL  1/11/2023        SP
# 64     230341   WC       water column      IRL  1/11/2023        SP
# 65     230420   OW    overlying water      IRL  1/26/2023        SP
# 66     230421   RZ  pore water rhizon      IRL  1/26/2023        SP
# 67     230422   RZ  pore water rhizon      IRL  1/26/2023        SP
# 68     230423   RZ  pore water rhizon      IRL  1/26/2023        SP
# 69     230424   RZ  pore water rhizon      IRL  1/26/2023        SP
# 70     230425   RZ  pore water rhizon      IRL  1/26/2023        SP
# 71     230426   RZ  pore water rhizon      IRL  1/26/2023        SP
# 72     230427   RZ  pore water rhizon      IRL  1/26/2023        SP
# 73     230430   WC       water column      IRL  1/26/2023        SP
#
#          Region  Depth   NPOC_mgL     TN_mgL  ...  ss_275_700_hm  \
# 34  Saint Lucie    0.5   7.509000   1.726125  ...       4.713333
# 28  Saint Lucie      S   7.573500   0.497950  ...       4.520052
# 35  Saint Lucie    0.5  19.087500   3.230625  ...       3.939073
# 30  Saint Lucie      S  15.095000   0.961900  ...       4.491071
# 29  Saint Lucie      S  14.940000   0.847850  ...       4.360911
# 33  Saint Lucie    0.5   9.075000   1.573125  ...       5.839818
# 27  Saint Lucie      S   4.416000   0.286800  ...       5.462546
# 14      Central      0   3.805000   0.261950  ...       4.599715
# 15      Central    0.5   4.143243   0.307703  ...       5.187004
# 16      Central      1   4.420541   0.425595  ...       4.647501
# 17      Central    1.5   5.702500   0.760083  ...       4.965685
# 18      Central      2  11.920000   2.148667  ...       6.083760
# 19      Central    2.5   5.904643   0.928500  ...       4.252910
# 20      Central      3   5.742500   0.934583  ...       6.899327
# 21      Central    3.5   6.485143   1.170343  ...       6.718955
# 22      Central      4  11.764500   2.540700  ...       7.400625
# 23      Central    4.5   5.131667   0.782750  ...       6.108104
# 24      Central      S   3.427500   0.267450  ...       4.675347
# 25      Central      B   3.500500   0.291200  ...       4.931279
# 32      Central    0.5  71.538750  32.523750  ...       1.381755
# 26      Central      S   9.862000   0.592150  ...       4.447259
# 1       Central      0   3.352667   0.222350  ...       4.013100
# 2       Central    0.5   5.463750   0.488732  ...       4.896782
# 3       Central      1   7.380000   0.840900  ...       5.791106
# 4       Central    1.5   6.256875   1.155188  ...            NaN
# 5       Central      2   5.052907   1.034826  ...       4.757100
# 6       Central    2.5   6.690441   1.419926  ...       5.308150
# 7       Central      3        NaN        NaN  ...            NaN
# 8       Central    3.5  11.079231   2.827154  ...       5.809775
# 9       Central      4  12.362143   3.279643  ...       5.930337
# 10      Central    4.5   7.620000   2.153000  ...       5.389932
# 11      Central      5        NaN        NaN  ...       8.744094
# 12      Central      B   1.856500   0.135100  ...       5.474839
# 13      Central      S   3.907500   0.228850  ...       4.580298
# 36      Central    0.5   9.870000   1.333500  ...       4.918090
# 31      Central      S   6.839500   0.458700  ...       5.488618
# 50        North   0.25  14.730750   1.149750  ...       7.246168
# 51        North   0.75  18.217500   1.179675  ...       6.517370
# 52        North    1.5  15.773306   1.023299  ...       7.247652
# 53        North    2.5  20.617500   1.613250  ...       6.859708
# 54        North    3.5  36.654000   4.145511  ...       7.686192
# 55        North    4.5  25.215000   2.726250  ...       7.669183
# 56        North    5.5  41.526167   5.224450  ...       7.784460
# 57        North    6.5  34.548750   4.486250  ...       7.596880
# 58        North    7.5  33.263000   3.053845  ...       7.276733
# 59        North    8.5  17.047650   1.838600  ...       7.126436
# 60        North    9.5  47.258250   3.967325  ...       6.841683
# 61        North   9.75  38.136000   3.780000  ...       7.245131
# 62        North  11.25  32.340000   2.867550  ...       7.380786
# 63        North      S  12.430000   0.781050  ...       6.479357
# 64        North      S  12.360000   0.758100  ...       6.672574
# 65        North      0  13.935000   0.888650  ...       5.378358
# 66        North    0.5  18.255000   1.237650  ...       7.261557
# 67        North      1  18.832500   1.236075  ...       7.305917
# 68        North    1.5  20.370000   1.330125  ...       6.654340
# 69        North      2  18.757500   1.299000  ...       7.233124
# 70        North      3  21.150000   1.582500  ...       7.454347
# 71        North      4  20.167500   1.639500  ...       6.759924
# 72        North      5  19.372500   1.635000  ...       7.293808
# 73        North      S  13.455000   0.839550  ...       5.159877
#
#     ss_275_295_hm  ss_350_400_hm      SR_hm  temp_val  temp_rmse  \
# 34       0.018695       2.666181   0.006885 -2.771457   0.148710
# 28       2.537821       2.713314   0.950236 -1.321040   0.162561
# 35       0.005542       3.291982   0.001685 -2.965148   0.148441
# 30       1.732951       3.528930   0.490655 -1.315719   0.159105
# 29       1.654151       3.338490   0.495673 -0.972043   0.157262
# 33       0.724681       4.178215   0.176458 -0.581301   0.166943
# 27       3.620100       3.139728   1.151127 -0.839751   0.151029
# 14       1.572499       2.439026   0.645679  0.547077   0.129958
# 15       1.699845       1.639439   1.189338  3.324537   0.171194
# 16       1.384267       2.162995   0.641213  6.870346   0.177320
# 17       0.006505       2.982679   0.002244 -2.286371   0.148880
# 18       0.004023       3.914205   0.001028  2.245638   0.162962
# 19       0.287046       4.711244   0.068545 -2.427537   0.135751
# 20       0.005071       1.466298  -2.057351  2.262277   0.139712
# 21       0.003809       6.270866   0.000608  0.344290   0.164735
# 22       0.003504       6.235065   0.000562 -0.129518   0.164492
# 23       0.003955       6.384474   0.000624  0.447217   0.140392
# 24       1.580384       4.567022   0.343184  1.615289   0.134465
# 25       1.430193       4.109797   0.349906 -1.568571   0.124909
# 32       0.102557       0.001178  83.349470 -9.976539   0.210257
# 26       2.910127       3.219424   0.906161 -2.517360   0.167121
# 1        1.389971       4.521167   0.309952  0.275971   0.157906
# 2        2.677208       5.174589   0.518583  1.376689   0.170929
# 3        0.607684       4.835333   0.123895  4.523100   0.174293
# 4             NaN            NaN        NaN       NaN        NaN
# 5        0.008637       3.532578   0.002463  0.708606   0.166547
# 6        0.411782       4.207803   0.097873  1.875616   0.201901
# 7             NaN            NaN        NaN       NaN        NaN
# 8        0.003562       4.005011   0.000890  4.162019   0.175929
# 9        0.003343       4.020656   0.000836  3.250529   0.188987
# 10       0.003723       3.504060   0.001064 -2.468443   0.147646
# 11       0.003033       5.230879   0.000583  1.162783   0.149213
# 12       0.058024       2.964809   0.021984  0.600185   0.146686
# 13       0.194146       3.290691   0.053262 -0.023324   0.146711
# 36       1.196949       3.780179   0.318118 -1.376323   0.170099
# 31       3.571856       3.458185   1.034990 -0.112948   0.157026
# 50       2.609240       6.131899   0.425751 -0.904692   0.145874
# 51       4.880098       4.860032   1.004841 -3.083568   0.146206
# 52       5.575991       6.028702   0.926775 -0.736782   0.143893
# 53       6.127108       6.640112   0.924178 -0.840618   0.116055
# 54       0.003785       7.496367   0.000506 -1.054467   0.136540
# 55       0.003898       7.074252   0.000553 -0.933230   0.134497
# 56       2.825331       7.445326   0.380269  0.133375   0.142336
# 57       3.099640       7.244037   0.427555 -0.040898   0.142042
# 58       0.031247       7.028989   0.004648 -0.698837   0.122197
# 59       6.062225       6.197484   0.978644 -1.857350   0.115416
# 60       5.709139       6.317963   0.906047 -0.474562   0.138438
# 61       1.231918       6.602715   0.186353 -0.455326   0.134767
# 62       1.244336       3.579572   0.349333 -0.219888   0.133918
# 63       4.730463       5.240240   0.903395 -1.573998   0.119842
# 64       4.574294       5.199637   0.879919 -1.588025   0.126737
# 65       2.174627       4.907416   0.443304 -2.453073   0.185722
# 66       2.037147       6.090798   0.334467  2.204635   0.169694
# 67       2.275242       6.157553   0.369221  2.582838   0.192626
# 68       1.382769       5.022990   0.276305  1.793862   0.136862
# 69       1.139400       4.933233   0.231692  0.623089   0.126316
# 70       1.273065       5.538350   0.230530  0.589932   0.124605
# 71       1.900008       5.030976   0.378005 -0.848101   0.159264
# 72       2.236283       5.095222   0.440138 -0.056036   0.131775
# 73       1.949707       6.057615   0.320851 -5.533123   0.246769
#
#     mean_700_725   fet/doc      doc/fet  log.fet/doc
# 34      0.576723  0.000000          inf         -inf
# 28      0.503908  0.001106   904.061023    -9.820276
# 35      0.239629  0.000000          inf         -inf
# 30      1.162625  0.002336   427.993830    -8.741446
# 29      2.329536  0.003402   293.985690    -8.199602
# 33      0.423964  0.000000          inf         -inf
# 27     -0.093937  0.000949  1053.837342   -10.041436
# 14     -2.712754  0.000341  2928.442001   -11.515918
# 15      0.101937  0.000407  2455.955078   -11.262068
# 16      0.138477  0.000695  1439.866607   -10.491719
# 17     -1.031636  0.000713  1402.500009   -10.453785
# 18     -0.834234  0.000000          inf         -inf
# 19      0.858874  0.002104   475.221145    -8.892455
# 20     -8.843194  0.002637   379.210626    -8.566856
# 21     -1.839526  0.002594   385.534138    -8.590715
# 22     -2.627201  0.000607  1646.165158   -10.684893
# 23     -2.110417  0.001128   886.164435    -9.791431
# 24      4.518807  0.000313  3195.454743   -11.641806
# 25     -0.391937  0.000412  2428.303703   -11.245733
# 32      2.890803  0.000000          inf         -inf
# 26     -0.001181  0.001610   621.283137    -9.279107
# 1       4.293010  0.001602   624.121570    -9.285683
# 2      -2.687774  0.002859   349.778929    -8.450300
# 3       0.212786  0.001373   728.131892    -9.508056
# 4            NaN  0.003023   330.843157    -8.370004
# 5      -4.810313  0.004640   215.514327    -7.751640
# 6      -2.420646  0.000781  1279.841887   -10.321750
# 7            NaN       NaN          NaN          NaN
# 8      -2.388240  0.002623   381.171355    -8.574296
# 9      -2.427751  0.003087   323.963480    -8.339687
# 10     -1.922268  0.003639   274.784664    -8.102158
# 11      0.175304       NaN          NaN          NaN
# 12     -0.158845  0.004288   233.233791    -7.865633
# 13      0.068394  0.001392   718.555284    -9.488955
# 36     -0.477540  0.000000          inf         -inf
# 31     -0.416282  0.000758  1319.959086   -10.366277
# 50      3.562425  0.000000          inf         -inf
# 51      1.203223  0.000000          inf         -inf
# 52      0.002972  0.000000          inf         -inf
# 53     -2.146713  0.000000          inf         -inf
# 54     -0.535321  0.000000          inf         -inf
# 55     -0.610278  0.000000          inf         -inf
# 56     -0.231934  0.000000          inf         -inf
# 57     -0.229088  0.000000          inf         -inf
# 58     -1.858218  0.000000          inf         -inf
# 59      0.421151  0.000000          inf         -inf
# 60     -0.715181  0.000000          inf         -inf
# 61     -1.152333  0.000000          inf         -inf
# 62     -1.480048  0.000000          inf         -inf
# 63     -1.229841  0.000000          inf         -inf
# 64      0.156964  0.000000          inf         -inf
# 65     -5.344366  0.000000          inf         -inf
# 66      0.332860  0.000000          inf         -inf
# 67      1.159351  0.000000          inf         -inf
# 68     -1.916518  0.000000          inf         -inf
# 69      0.324025  0.000000          inf         -inf
# 70      0.495943  0.000000          inf         -inf
# 71     -2.549955  0.000000          inf         -inf
# 72     -0.126517  0.000000          inf         -inf
# 73     17.173839  0.000000          inf         -inf
#
# [60 rows x 37 columns]

# %%
##GET RHZ CORES 
ds_grouped = df.groupby(["Location"])
ds_rz = ds_grouped.get_group("SP")
ds_locs = ds_rz.groupby(["Type"])
ds_locs.groups.keys()


##PLOT RHZ CORES 

#ds = ds_rz

##Shorty's pocket RZ
ds = ds_locs.get_group("RZ")
titel = "Rhizon Core"

sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(4,10))

X = ds["NPOC_uM"] #X var 
X = np.asarray(X, dtype=float).ravel()
Y = ds['Depth'] #Y var
Y = np.asarray(Y, dtype=float).ravel()
X1 = ds['TN_uM'] #X var 
X1 = np.asarray(X1, dtype=float).ravel()
X2 = ds['acdom412'] #X var 
X2 = np.asarray(X2, dtype=float).ravel()
X3 = ds['Fe3_uM'] #X var 
X3 = np.asarray(X3, dtype=float).ravel()

Z = None #color

ax.plot(X, Y, 'o', ls='-', c='b')
ax.set_ylim(12,-.5)
ax.set_xlim(100,4100)
ax.set_xlabel("DOC uM", size = 15, c='b')
ax.set_ylabel("Depth (cm)", size = 15)
ax.set_title(titel, size = 18)
ax.axhline(y=0, color='black', linestyle='-', label='Sediment Water Interface')
ax.text(125, -.05, 'Sediment Water Interface', fontsize=10)

ax2 = ax.twiny()
ax2.plot(X1, Y,'o', ls='-', c='orange')
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 50))
ax2.set_xlabel('TN uM', size= 15, c='orange')
min_val1 = 0
max_val1 = 500
ax2.set_xlim(min_val1,max_val1)

ax3 = ax2.twiny()
ax3.plot(X2, Y,'o', ls='-', c='g')
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
ax3.xaxis.set_ticks_position('bottom')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 100))
ax3.set_xlabel('aCDOM 412 nm', size= 15, c='g')
min_val2 = -4
max_val2 = 15
ax3.set_xlim(min_val2,max_val2)

plt.tight_layout()

plt.savefig('../../../IRL22SU/Plots/Shorty_Pocket_RZ.png')

# %%
##GET RHZ CORES 
ds_grouped = df.groupby(["Location"])
ds_rz = ds_grouped.get_group("SP")
ds_locs = ds_rz.groupby(["Type"])
ds_locs.groups.keys()


##PLOT RHZ CORES 

#ds = ds_rz

##Shorty's pocket PW
ds = ds_locs.get_group("PW")
titel = "Sectioning core"

sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(4,10))

X = ds["NPOC_uM"] #X var 
X = np.asarray(X, dtype=float).ravel()
Y = ds['Depth'] #Y var
Y = np.asarray(Y, dtype=float).ravel()
X1 = ds['TN_uM'] #X var 
X1 = np.asarray(X1, dtype=float).ravel()
X2 = ds['acdom412'] #X var 
X2 = np.asarray(X2, dtype=float).ravel()
X3 = ds['Fe3_uM'] #X var 
X3 = np.asarray(X3, dtype=float).ravel()

Z = None #color

ax.plot(X, Y, 'o', ls='-', c='b')
ax.set_ylim(12,-.5)
ax.set_xlim(100,4100)
ax.set_xlabel("DOC uM", size = 15, c='b')
ax.set_ylabel("Depth (cm)", size = 15)
ax.set_title(titel, size = 18)
ax.axhline(y=0, color='black', linestyle='-', label='Sediment Water Interface')
ax.text(125, -.05, 'Sediment Water Interface', fontsize=10)

ax2 = ax.twiny()
ax2.plot(X1, Y,'o', ls='-', c='orange')
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 50))
ax2.set_xlabel('TN uM', size= 15, c='orange')
min_val1 = 0
max_val1 = 500
ax2.set_xlim(min_val1,max_val1)

ax3 = ax2.twiny()
ax3.plot(X2, Y,'o', ls='-', c='g')
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
ax3.xaxis.set_ticks_position('bottom')
ax3.xaxis.set_label_position('bottom')
ax3.spines['bottom'].set_position(('outward', 100))
ax3.set_xlabel('aCDOM 412 nm', size= 15, c='g')
min_val2 = -4
max_val2 = 15
ax3.set_xlim(min_val2,max_val2)

plt.tight_layout()

plt.savefig('../../../IRL22SU/Plots/Shorty_Pocket_PW.png')

# %%
#PART 2

# %%
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy as np
# %matplotlib inline
import cmocean
import cmocean.cm as cmo

# %%
files = glob.glob('../../../IRL22SU/IRL_SHORT_DATA.csv')

def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)

# %%
# Change this!
lat_top=29
lat_bot=27.0
lon_left=-80.9
lon_rigth=-80
extent=[lon_left, lon_rigth, lat_bot, lat_top]

# set resolution of the features in map: '10m', '50m', or '110m'.  
# If you do this the first time it will take a while downloading the coastline 
# and other features. In the future it will be faster
res = '10m'

#Figure

fig = plt.figure(figsize=(30,15)) # set fig size. You will probably want to change this
ax = fig.add_subplot(111, projection=ccrs.PlateCarree()) #set cartographic projection. There are a bunch
ax.set_extent(extent) # set the extent, or the box of the map
ax.coastlines(res) # set coastilines, and resolution 

#land
ax.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='land',
                                            facecolor='grey', # change color here
                                            scale=res)) 
#Rivers
ax.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='rivers_lake_centerlines',
                                            edgecolor='blue', # change color here
                                            facecolor='none',
                                            scale=res))

#Gir. Only if you want one:
gl = ax.gridlines(xlocs=np.arange(lon_left, lon_rigth+1),
                  ylocs=np.arange(lat_bot, lat_top+1),
                  draw_labels=True, 
                  linewidth=0.5, color='k', linestyle=':')
gl.top_labels = gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# %%
#making it a function

def plot_mapbase(extent, res='10m', projection=ccrs.PlateCarree()):
    fig = plt.figure(figsize=(30,15)) # set fig size
    ax = fig.add_subplot(111, projection=projection)
    ax.set_extent(extent)
    ax.coastlines(res)
    ax.coastlines(resolution='10m', color='black', linestyle='-', alpha=1)
    #gl = ax.gridlines(xlocs=np.arange(lon_left, lon_rigth+1),
    #                  ylocs=np.arange(lat_bot, lat_top+1),
    #                  draw_labels=True, 
    #                  linewidth=0.5, color='k', linestyle=':')
    #gl.top_labels = gl.right_labels = False
    #gl.xformatter = LONGITUDE_FORMATTER
    #gl.yformatter = LATITUDE_FORMATTER
    #gl.xlabel_style = {'size': 15, 'color': 'black'}
    #gl.ylabel_style = {'size': 15, 'color': 'black'}
    return fig, ax

fig, ax = plot_mapbase(extent)

# %%
df_grouped = df.groupby(by="CAT")

df_water = df_grouped.get_group("W")
df_mud = df_grouped.get_group("M")

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df['LON'], df['LAT'], # lon, lat variable as x,y
           c=df['acdom412'],
           edgecolor='k',  #you color variable
           #vmin=10, vmax=100, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.matter, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.565, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
#ax.text(-80.26,28.3, 'Surface Water\n'+'a$_{CDOM}$ (412 nm) (1/m)', size=10, rotation=90)
#cb.set_label('Surface Water\n'+'a$_{CDOM}$ (412 nm) (1/m)', size=10, verticalalignment='left')

fig.set_size_inches(20,10)

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_water['LON'], df_water['LAT'], # lon, lat variable as x,y
           c=df_water['acdom412'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=35, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.matter, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.565, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.24,28.3, 'a$_{CDOM}$ (412 nm) (1/m)', size=11, rotation=90)
ax.set_title("Water Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/water_cdom_map.png')

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_mud['LON'], df_mud['LAT'], # lon, lat variable as x,y
           c=df_mud['acdom412'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=35, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.matter, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.565, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.24,28.3, 'a$_{CDOM}$ (412 nm) (1/m)', size=11, rotation=90)
ax.set_title("Sediment Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/mud_cdom_map.png')

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_water['LON'], df_water['LAT'], # lon, lat variable as x,y
           c=df_water['NPOC_uM'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=2000, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.deep, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.558, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.27,28.4, 'DOC (uM)', size=11, rotation=90)
ax.set_title("Water Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/water_DOC_map.png')

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_mud['LON'], df_mud['LAT'], # lon, lat variable as x,y
           c=df_mud['NPOC_uM'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=2000, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.deep, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.558, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.27,28.4, 'DOC (uM)', size=11, rotation=90)
ax.set_title("Sediment Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/mud_DOC_map.png')

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_water['LON'], df_water['LAT'], # lon, lat variable as x,y
           c=df_water['FeT_uM'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=4, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.dense, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.565, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.24,28.4, 'Iron Total (uM)', size=11, rotation=90)
ax.set_title("Water Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/water_FeT_map.png')

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df_mud['LON'], df_mud['LAT'], # lon, lat variable as x,y
           c=df_mud['FeT_uM'],
           edgecolor='k',  #you color variable
           vmin=0, vmax=4, # This is usefull if you want to compare maps and want to set a fixed min and max value
           cmap= cmo.dense, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
cax = fig.add_axes([.565, .55, .01, .30])
cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.24,28.4, 'Iron Total (uM)', size=11, rotation=90)
ax.set_title("Sediment Samples", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/mud_FeT_map.png')

# %%
files = glob.glob('../../../IRL22SU/IRL_LOCS_DATES.csv')

def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)

# %%
fig, ax = plot_mapbase(extent)
mappable = ax.scatter(df['LON'], df['LAT'], # lon, lat variable as x,y
           c="black",
           edgecolor='k',  #you color variable
           #vmin=10, vmax=100, # This is usefull if you want to compare maps and want to set a fixed min and max value
           #cmap= cmo.phase, # colormap. look for other colormaps https://matplotlib.org/stable/tutorials/colors/colormaps.html
           s=300, # your size variable. Can get rid if don't need
           transform=ccrs.PlateCarree())
#cax = fig.add_axes([.565, .55, .01, .30])
#cb = fig.colorbar(mappable, cax=cax)
ax.text(-80.24,27.4, 'Bear Point', size=13, rotation=0)
ax.text(-80.3,27.58, 'Secret Beach', size=13, rotation=0)
ax.text(-80.58,28.29, "Shorty's Pocket", size=13, rotation=0)
ax.set_title("Locations", size = 18, y=.95)
fig.set_size_inches(20,10)

plt.savefig('../../../IRL22SU/Plots/loc_map.png')
